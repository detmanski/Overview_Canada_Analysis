# %%
import os
import pandas as pd

# %%
bc_string = 'Resources/ON_Cultural_Participation.csv'
bc_df = pd.read_csv(bc_string)
bc_df.head()
# Out:
#    REF_DATE      GEO        DGUID                 Age group         Sex  \
# 0      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 1      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 2      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 3      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 4      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# 0                        Making music      Number of persons  Persons     249
# 1                        Making music  Percentage of persons  Percent     239
# 2                             Theatre      Number of persons  Persons     249
# 3                             Theatre  Percentage of persons  Percent     239
# 4  Audio-visual and interactive media      Number of persons  Persons     249
#
#   SCALAR_FACTOR  SCALAR_ID      VECTOR     COORDINATE   VALUE STATUS  SYMBOL  \
# 0     thousands          3  v119530232  8.1.1.1.1.1.1  1847.0    NaN     NaN
# 1         units          0  v119530233  8.1.1.1.1.1.2    15.8    NaN     NaN
# 2     thousands          3  v119530236  8.1.1.1.1.2.1   217.0      E     NaN
# 3         units          0  v119530237  8.1.1.1.1.2.2     1.9      E     NaN
# 4     thousands          3  v119530240  8.1.1.1.1.3.1   624.0    NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         1
# 2         NaN         0
# 3         NaN         1
# 4         NaN         0

# %%
bc_df.drop(columns=["Percieved health"], inplace=True)
bd_df
# Out:
#   File "/var/folders/mc/ktgbqxj54dd2hpjj2g0t7x4c0000gn/T/ipykernel_28404/3659335829.py", line 1
#     bc_df.drop(columns=[]"Percieved health"], inplace=True)
#                                           ^
# SyntaxError: invalid syntax

# %%
mb_string = 'Resources/MB_Cultural_Participation.csv'
mb_df = pd.read_csv(mb_string)
mb_df.head()
# Out:
#    REF_DATE     GEO           DGUID                 Age group         Sex  \
# 0      2016  Canada  2016A000011124  Total, 15 years and over  Both sexes
# 1      2016  Canada  2016A000011124  Total, 15 years and over  Both sexes
# 2      2016  Canada  2016A000011124  Total, 15 years and over  Both sexes
# 3      2016  Canada  2016A000011124  Total, 15 years and over  Both sexes
# 4      2016  Canada  2016A000011124  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# 0                        Making music      Number of persons  Persons     249
# 1                        Making music  Percentage of persons  Percent     239
# 2                             Theatre      Number of persons  Persons     249
# 3                             Theatre  Percentage of persons  Percent     239
# 4  Audio-visual and interactive media      Number of persons  Persons     249
#
#   SCALAR_FACTOR  SCALAR_ID      VECTOR     COORDINATE   VALUE  STATUS  SYMBOL  \
# 0     thousands          3  v119258072  1.1.1.1.1.1.1  4374.0     NaN     NaN
# 1         units          0  v119258073  1.1.1.1.1.1.2    14.5     NaN     NaN
# 2     thousands          3  v119258076  1.1.1.1.1.2.1   415.0     NaN     NaN
# 3         units          0  v119258077  1.1.1.1.1.2.2     1.4     NaN     NaN
# 4     thousands          3  v119258080  1.1.1.1.1.3.1  1240.0     NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         1
# 2         NaN         0
# 3         NaN         1
# 4         NaN         0

# %%
mb_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)

# %%
mb_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)

# %%
mb_df
# Out:
#        GEO                         Cultural activities              Estimates  \
# 0   Canada                                Making music      Number of persons
# 1   Canada                                Making music  Percentage of persons
# 2   Canada                                     Theatre      Number of persons
# 3   Canada                                     Theatre  Percentage of persons
# 4   Canada          Audio-visual and interactive media      Number of persons
# 5   Canada          Audio-visual and interactive media  Percentage of persons
# 6   Canada                                     Dancing      Number of persons
# 7   Canada                                     Dancing  Percentage of persons
# 8   Canada                                 Visual arts      Number of persons
# 9   Canada                                 Visual arts  Percentage of persons
# 10  Canada                                    Crafting      Number of persons
# 11  Canada                                    Crafting  Percentage of persons
# 12  Canada                                     Writing      Number of persons
# 13  Canada                                     Writing  Percentage of persons
# 14  Canada                   Other cultural activities      Number of persons
# 15  Canada                   Other cultural activities  Percentage of persons
# 16  Canada  Did not participate in cultural activities      Number of persons
# 17  Canada  Did not participate in cultural activities  Percentage of persons
#
#         UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID
# 0   Persons     249     thousands          3
# 1   Percent     239         units          0
# 2   Persons     249     thousands          3
# 3   Percent     239         units          0
# 4   Persons     249     thousands          3
# 5   Percent     239         units          0
# 6   Persons     249     thousands          3
# 7   Percent     239         units          0
# 8   Persons     249     thousands          3
# 9   Percent     239         units          0
# 10  Persons     249     thousands          3
# 11  Percent     239         units          0
# 12  Persons     249     thousands          3
# 13  Percent     239         units          0
# 14  Persons     249     thousands          3
# 15  Percent     239         units          0
# 16  Persons     249     thousands          3
# 17  Percent     239         units          0
