# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# %%
# List of cities
cities = ["St. John's", 'Halifax', 'Québec', 'Sherbrooke', 'Montréal',
       'Ottawa', 'Gatineau', 'Oshawa', 'Toronto',
       'Hamilton', 'St. Catharines',
       'Kitchener', 'London', 'Windsor', 'Barrie',
       'Winnipeg', 'Regina', 'Saskatoon', 'Calgary', 'Edmonton',
       'Kelowna', 'Abbotsford', 'Vancouver', 'Victoria']

# %%
#["St. John's", 'Halifax', 'Québec', 'Sherbrooke', 'Montréal','Ottawa - Gatineau', 'Ottawa - Gatineau (Quebec part)','Ottawa - Gatineau (Ontario part)', 'Oshawa', 'Toronto','Hamilton', 'St. Catharines - Niagara','Kitchener - Cambridge - Waterloo', 'London', 'Windsor', 'Barrie','Winnipeg', 'Regina', 'Saskatoon', 'Calgary', 'Edmonton','Kelowna', 'Abbotsford - Mission', 'Vancouver', 'Victoria']

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"
       
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response_json = requests.get(city_url).json()
        #json.dumps(response_json, indent=4, sort_keys=True)
        #city_weather = response_json["weather"]
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json["coord"]["lat"]
        city_lng = response_json["coord"]["lon"]
        city_max_temp = response_json["main"]["temp_max"]
        city_humidity = response_json["main"]["humidity"]
        city_clouds = response_json["clouds"]["all"]
        city_wind = response_json["wind"]["speed"]
        city_country = response_json["sys"]["country"]
        city_date = response_json["dt"]
      

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | St. John's
# Processing Record 2 of Set 1 | Halifax
# Processing Record 3 of Set 1 | Québec
# Processing Record 4 of Set 1 | Sherbrooke
# Processing Record 5 of Set 1 | Montréal
# Processing Record 6 of Set 1 | Ottawa
# Processing Record 7 of Set 1 | Gatineau
# Processing Record 8 of Set 1 | Oshawa
# Processing Record 9 of Set 1 | Toronto
# Processing Record 10 of Set 1 | Hamilton
# Processing Record 11 of Set 1 | St. Catharines
# Processing Record 12 of Set 1 | Kitchener
# Processing Record 13 of Set 1 | London
# Processing Record 14 of Set 1 | Windsor
# Processing Record 15 of Set 1 | Barrie
# Processing Record 16 of Set 1 | Winnipeg
# Processing Record 17 of Set 1 | Regina
# Processing Record 18 of Set 1 | Saskatoon
# Processing Record 19 of Set 1 | Calgary
# Processing Record 20 of Set 1 | Edmonton
# Processing Record 21 of Set 1 | Kelowna
# Processing Record 22 of Set 1 | Abbotsford
# Processing Record 23 of Set 1 | Vancouver
# Processing Record 24 of Set 1 | Victoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Find out how many cities were found
len(city_data)
# Out:
# 24

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          24
# Lat           24
# Lng           24
# Max Temp      24
# Humidity      24
# Cloudiness    24
# Wind Speed    24
# Country       24
# Date          24
# dtype: int64

# %%
# Display sample data
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       St. John's  47.5649  -52.7093     -0.57        82          75
# 1          Halifax  44.6453  -63.5724      0.25        38          20
# 2           Québec  46.8123  -71.2145     -1.00        68          75
# 3       Sherbrooke  45.4001  -71.8991      0.32        72           0
# 4         Montréal  45.5088  -73.5878      1.86        82         100
# 5           Ottawa  45.4112  -75.6981     -0.74        91         100
# 6         Gatineau  45.4772  -75.7016     -0.43        89         100
# 7           Oshawa  43.9001  -78.8496      2.60        99         100
# 8          Toronto  43.7001  -79.4163      2.95        94         100
# 9         Hamilton  39.1834  -84.5333     19.21        71         100
# 10  St. Catharines  43.1668  -79.2496      6.47        97         100
# 11       Kitchener  43.4254  -80.5112      1.45        96         100
# 12          London  51.5085   -0.1257      9.59        62          96
# 13         Windsor  42.3001  -83.0165      5.06        98         100
# 14          Barrie  44.4001  -79.6663      1.68        95         100
# 15        Winnipeg  49.8844  -97.1470     -9.99        74          20
# 16          Regina  50.4501 -104.6178     -8.87        84          20
# 17       Saskatoon  52.1168 -106.6345    -11.01        85           0
# 18         Calgary  51.0501 -114.0853     -2.93        60          75
# 19        Edmonton  53.5501 -113.4687     -4.68        70          75
# 20         Kelowna  49.8831 -119.4857      3.98        87         100
# 21      Abbotsford  49.0580 -122.2526      4.66        91         100
# 22       Vancouver  49.2497 -123.1193      5.57        92         100
# 23        Victoria  22.2855  114.1577     21.08        86          88
#
#     Wind Speed Country        Date
# 0         9.26      CA  1675960609
# 1         8.23      CA  1675960073
# 2         2.57      CA  1675960610
# 3         2.06      CA  1675960395
# 4         3.09      CA  1675960427
# 5         6.17      CA  1675959755
# 6         6.17      CA  1675960566
# 7         6.17      CA  1675960317
# 8        10.29      CA  1675960399
# 9         9.77      US  1675960527
# 10        3.09      CA  1675960457
# 11        3.60      CA  1675960569
# 12        2.57      GB  1675959758
# 13        3.09      CA  1675960603
# 14        4.12      CA  1675960612
# 15        7.20      CA  1675960466
# 16        2.24      CA  1675960539
# 17        5.14      CA  1675960323
# 18        2.06      CA  1675960515
# 19        1.79      CA  1675959961
# 20        2.06      CA  1675960463
# 21        3.09      CA  1675960571
# 22        4.12      CA  1675960019
# 23        2.24      HK  1675960491

# %%
city_data_df.index.name = 'City_IDWeather'
city_data_df
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_IDWeather
# 0                   St. John's  47.5649  -52.7093     -0.57        82
# 1                      Halifax  44.6453  -63.5724      0.25        38
# 2                       Québec  46.8123  -71.2145     -1.00        68
# 3                   Sherbrooke  45.4001  -71.8991      0.32        72
# 4                     Montréal  45.5088  -73.5878      1.86        82
# 5                       Ottawa  45.4112  -75.6981     -0.74        91
# 6                     Gatineau  45.4772  -75.7016     -0.43        89
# 7                       Oshawa  43.9001  -78.8496      2.60        99
# 8                      Toronto  43.7001  -79.4163      2.95        94
# 9                     Hamilton  39.1834  -84.5333     19.21        71
# 10              St. Catharines  43.1668  -79.2496      6.47        97
# 11                   Kitchener  43.4254  -80.5112      1.45        96
# 12                      London  51.5085   -0.1257      9.59        62
# 13                     Windsor  42.3001  -83.0165      5.06        98
# 14                      Barrie  44.4001  -79.6663      1.68        95
# 15                    Winnipeg  49.8844  -97.1470     -9.99        74
# 16                      Regina  50.4501 -104.6178     -8.87        84
# 17                   Saskatoon  52.1168 -106.6345    -11.01        85
# 18                     Calgary  51.0501 -114.0853     -2.93        60
# 19                    Edmonton  53.5501 -113.4687     -4.68        70
# 20                     Kelowna  49.8831 -119.4857      3.98        87
# 21                  Abbotsford  49.0580 -122.2526      4.66        91
# 22                   Vancouver  49.2497 -123.1193      5.57        92
# 23                    Victoria  22.2855  114.1577     21.08        86
#
#                 Cloudiness  Wind Speed Country        Date
# City_IDWeather
# 0                       75        9.26      CA  1675960609
# 1                       20        8.23      CA  1675960073
# 2                       75        2.57      CA  1675960610
# 3                        0        2.06      CA  1675960395
# 4                      100        3.09      CA  1675960427
# 5                      100        6.17      CA  1675959755
# 6                      100        6.17      CA  1675960566
# 7                      100        6.17      CA  1675960317
# 8                      100       10.29      CA  1675960399
# 9                      100        9.77      US  1675960527
# 10                     100        3.09      CA  1675960457
# 11                     100        3.60      CA  1675960569
# 12                      96        2.57      GB  1675959758
# 13                     100        3.09      CA  1675960603
# 14                     100        4.12      CA  1675960612
# 15                      20        7.20      CA  1675960466
# 16                      20        2.24      CA  1675960539
# 17                       0        5.14      CA  1675960323
# 18                      75        2.06      CA  1675960515
# 19                      75        1.79      CA  1675959961
# 20                     100        2.06      CA  1675960463
# 21                     100        3.09      CA  1675960571
# 22                     100        4.12      CA  1675960019
# 23                      88        2.24      HK  1675960491

# %%
cities_lookup_df = pd.read_csv('Resources/cities_lookup.csv')
#, encoding='ISO-8859-1'

cities_lookup_df
# Out:
#     City_ID                              City  City_ID2  \
# 0         0                        St. John's   18372.0
# 1         1                           Halifax   18426.0
# 2         2                            Québec   18534.0
# 3         3                        Sherbrooke   18552.0
# 4         4                          Montréal   18588.0
# 5         5                 Ottawa - Gatineau   18642.0
# 6         6   Ottawa - Gatineau (Quebec part)   18606.0
# 7         7  Ottawa - Gatineau (Ontario part)   18660.0
# 8         8                            Oshawa       NaN
# 9         9                           Toronto   18732.0
# 10       10                          Hamilton   18750.0
# 11       11          St. Catharines - Niagara   18768.0
# 12       12  Kitchener - Cambridge - Waterloo   18786.0
# 13       13                            London   18840.0
# 14       14                           Windsor   18858.0
# 15       15                            Barrie   18876.0
# 16       16                          Winnipeg   18948.0
# 17       17                            Regina   18984.0
# 18       18                         Saskatoon   19002.0
# 19       19                           Calgary   19056.0
# 20       20                          Edmonton   19074.0
# 21       21                           Kelowna   19110.0
# 22       22              Abbotsford - Mission   19128.0
# 23       23                         Vancouver   19146.0
# 24       24                          Victoria   19164.0
#
#                              GEO                            Province  \
# 0                     St. John's   Newfoundland and Labrador [10001]
# 1                        Halifax                 Nova Scotia [12205]
# 2                         Québec                      Quebec [24421]
# 3                     Sherbrooke                      Quebec [24433]
# 4                       Montréal                      Quebec [24462]
# 5                Ottawa-Gatineau        Ontario/Quebec [24505/35505]
# 6                Ottawa-Gatineau                 Quebec part [24505]
# 7                Ottawa-Gatineau                Ontario part [35505]
# 8                            NaN                                 NaN
# 9                        Toronto                     Ontario [35535]
# 10                      Hamilton                     Ontario [35537]
# 11         St.Catharines-Niagara                     Ontario [35539]
# 12  Kitchener-Cambridge-Waterloo                     Ontario [35541]
# 13                        London                     Ontario [35555]
# 14                       Windsor                     Ontario [35559]
# 15                        Barrie                     Ontario [35568]
# 16                      Winnipeg                    Manitoba [46602]
# 17                        Regina                Saskatchewan [47705]
# 18                     Saskatoon                Saskatchewan [47725]
# 19                       Calgary                     Alberta [48825]
# 20                      Edmonton                     Alberta [48835]
# 21                       Kelowna            British Columbia [59915]
# 22            Abbotsford-Mission            British Columbia [59932]
# 23                     Vancouver            British Columbia [59933]
# 24                      Victoria            British Columbia [59935]
#
#     City_IDWeather    Weather_City
# 0              0.0      St. John's
# 1              1.0         Halifax
# 2              2.0          Québec
# 3              3.0      Sherbrooke
# 4              4.0        Montréal
# 5              NaN             NaN
# 6              6.0        Gatineau
# 7              5.0          Ottawa
# 8              7.0          Oshawa
# 9              8.0         Toronto
# 10             9.0        Hamilton
# 11            10.0  St. Catharines
# 12            11.0       Kitchener
# 13            12.0          London
# 14            13.0         Windsor
# 15            14.0          Barrie
# 16            15.0        Winnipeg
# 17            16.0          Regina
# 18            17.0       Saskatoon
# 19            18.0         Calgary
# 20            19.0        Edmonton
# 21            20.0         Kelowna
# 22            21.0      Abbotsford
# 23            22.0       Vancouver
# 24            23.0        Victoria

# %%
columns_to_keep = ['City_IDWeather', 'GEO', 'City_ID2']
reduced_lookup_df = cities_lookup_df[columns_to_keep]
reduced_lookup_df
# Out:
#     City_IDWeather                           GEO  City_ID2
# 0              0.0                    St. John's   18372.0
# 1              1.0                       Halifax   18426.0
# 2              2.0                        Québec   18534.0
# 3              3.0                    Sherbrooke   18552.0
# 4              4.0                      Montréal   18588.0
# 5              NaN               Ottawa-Gatineau   18642.0
# 6              6.0               Ottawa-Gatineau   18606.0
# 7              5.0               Ottawa-Gatineau   18660.0
# 8              7.0                           NaN       NaN
# 9              8.0                       Toronto   18732.0
# 10             9.0                      Hamilton   18750.0
# 11            10.0         St.Catharines-Niagara   18768.0
# 12            11.0  Kitchener-Cambridge-Waterloo   18786.0
# 13            12.0                        London   18840.0
# 14            13.0                       Windsor   18858.0
# 15            14.0                        Barrie   18876.0
# 16            15.0                      Winnipeg   18948.0
# 17            16.0                        Regina   18984.0
# 18            17.0                     Saskatoon   19002.0
# 19            18.0                       Calgary   19056.0
# 20            19.0                      Edmonton   19074.0
# 21            20.0                       Kelowna   19110.0
# 22            21.0            Abbotsford-Mission   19128.0
# 23            22.0                     Vancouver   19146.0
# 24            23.0                      Victoria   19164.0

# %%
cities_lookup_df1 = reduced_lookup_df.dropna()
cities_lookup_df1
# Out:
#     City_IDWeather                           GEO  City_ID2
# 0              0.0                    St. John's   18372.0
# 1              1.0                       Halifax   18426.0
# 2              2.0                        Québec   18534.0
# 3              3.0                    Sherbrooke   18552.0
# 4              4.0                      Montréal   18588.0
# 6              6.0               Ottawa-Gatineau   18606.0
# 7              5.0               Ottawa-Gatineau   18660.0
# 9              8.0                       Toronto   18732.0
# 10             9.0                      Hamilton   18750.0
# 11            10.0         St.Catharines-Niagara   18768.0
# 12            11.0  Kitchener-Cambridge-Waterloo   18786.0
# 13            12.0                        London   18840.0
# 14            13.0                       Windsor   18858.0
# 15            14.0                        Barrie   18876.0
# 16            15.0                      Winnipeg   18948.0
# 17            16.0                        Regina   18984.0
# 18            17.0                     Saskatoon   19002.0
# 19            18.0                       Calgary   19056.0
# 20            19.0                      Edmonton   19074.0
# 21            20.0                       Kelowna   19110.0
# 22            21.0            Abbotsford-Mission   19128.0
# 23            22.0                     Vancouver   19146.0
# 24            23.0                      Victoria   19164.0

# %%
cities_lookup_df2 = cities_lookup_df1.astype({'City_ID2':'int', 'City_IDWeather':'int'})
cities_lookup_df2
# Out:
#     City_IDWeather                           GEO  City_ID2
# 0                0                    St. John's     18372
# 1                1                       Halifax     18426
# 2                2                        Québec     18534
# 3                3                    Sherbrooke     18552
# 4                4                      Montréal     18588
# 6                6               Ottawa-Gatineau     18606
# 7                5               Ottawa-Gatineau     18660
# 9                8                       Toronto     18732
# 10               9                      Hamilton     18750
# 11              10         St.Catharines-Niagara     18768
# 12              11  Kitchener-Cambridge-Waterloo     18786
# 13              12                        London     18840
# 14              13                       Windsor     18858
# 15              14                        Barrie     18876
# 16              15                      Winnipeg     18948
# 17              16                        Regina     18984
# 18              17                     Saskatoon     19002
# 19              18                       Calgary     19056
# 20              19                      Edmonton     19074
# 21              20                       Kelowna     19110
# 22              21            Abbotsford-Mission     19128
# 23              22                     Vancouver     19146
# 24              23                      Victoria     19164

# %%
merged_df = city_data_df.merge(cities_lookup_df2, on='City_IDWeather', how='inner')
merged_df
# Out:
#     City_IDWeather            City      Lat       Lng  Max Temp  Humidity  \
# 0                0      St. John's  47.5649  -52.7093     -0.57        82
# 1                1         Halifax  44.6453  -63.5724      0.25        38
# 2                2          Québec  46.8123  -71.2145     -1.00        68
# 3                3      Sherbrooke  45.4001  -71.8991      0.32        72
# 4                4        Montréal  45.5088  -73.5878      1.86        82
# 5                5          Ottawa  45.4112  -75.6981     -0.74        91
# 6                6        Gatineau  45.4772  -75.7016     -0.43        89
# 7                8         Toronto  43.7001  -79.4163      2.95        94
# 8                9        Hamilton  39.1834  -84.5333     19.21        71
# 9               10  St. Catharines  43.1668  -79.2496      6.47        97
# 10              11       Kitchener  43.4254  -80.5112      1.45        96
# 11              12          London  51.5085   -0.1257      9.59        62
# 12              13         Windsor  42.3001  -83.0165      5.06        98
# 13              14          Barrie  44.4001  -79.6663      1.68        95
# 14              15        Winnipeg  49.8844  -97.1470     -9.99        74
# 15              16          Regina  50.4501 -104.6178     -8.87        84
# 16              17       Saskatoon  52.1168 -106.6345    -11.01        85
# 17              18         Calgary  51.0501 -114.0853     -2.93        60
# 18              19        Edmonton  53.5501 -113.4687     -4.68        70
# 19              20         Kelowna  49.8831 -119.4857      3.98        87
# 20              21      Abbotsford  49.0580 -122.2526      4.66        91
# 21              22       Vancouver  49.2497 -123.1193      5.57        92
# 22              23        Victoria  22.2855  114.1577     21.08        86
#
#     Cloudiness  Wind Speed Country        Date                           GEO  \
# 0           75        9.26      CA  1675960609                    St. John's
# 1           20        8.23      CA  1675960073                       Halifax
# 2           75        2.57      CA  1675960610                        Québec
# 3            0        2.06      CA  1675960395                    Sherbrooke
# 4          100        3.09      CA  1675960427                      Montréal
# 5          100        6.17      CA  1675959755               Ottawa-Gatineau
# 6          100        6.17      CA  1675960566               Ottawa-Gatineau
# 7          100       10.29      CA  1675960399                       Toronto
# 8          100        9.77      US  1675960527                      Hamilton
# 9          100        3.09      CA  1675960457         St.Catharines-Niagara
# 10         100        3.60      CA  1675960569  Kitchener-Cambridge-Waterloo
# 11          96        2.57      GB  1675959758                        London
# 12         100        3.09      CA  1675960603                       Windsor
# 13         100        4.12      CA  1675960612                        Barrie
# 14          20        7.20      CA  1675960466                      Winnipeg
# 15          20        2.24      CA  1675960539                        Regina
# 16           0        5.14      CA  1675960323                     Saskatoon
# 17          75        2.06      CA  1675960515                       Calgary
# 18          75        1.79      CA  1675959961                      Edmonton
# 19         100        2.06      CA  1675960463                       Kelowna
# 20         100        3.09      CA  1675960571            Abbotsford-Mission
# 21         100        4.12      CA  1675960019                     Vancouver
# 22          88        2.24      HK  1675960491                      Victoria
#
#     City_ID2
# 0      18372
# 1      18426
# 2      18534
# 3      18552
# 4      18588
# 5      18660
# 6      18606
# 7      18732
# 8      18750
# 9      18768
# 10     18786
# 11     18840
# 12     18858
# 13     18876
# 14     18948
# 15     18984
# 16     19002
# 17     19056
# 18     19074
# 19     19110
# 20     19128
# 21     19146
# 22     19164

# %%
len(merged_df)
# Out:
# 23

# %%
# Export the merged_df into a csv

merged_df.to_csv("weather_data.csv", index_label="City_ID2")
