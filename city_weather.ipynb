# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# %%
# List of cities
cities = ["St. John's", 'Halifax', 'Québec', 'Sherbrooke', 'Montréal',
       'Ottawa', 'Gatineau', 'Oshawa', 'Toronto',
       'Hamilton', 'St. Catharines',
       'Kitchener', 'London', 'Windsor', 'Barrie',
       'Winnipeg', 'Regina', 'Saskatoon', 'Calgary', 'Edmonton',
       'Kelowna', 'Abbotsford', 'Vancouver', 'Victoria']

# %%
#["St. John's", 'Halifax', 'Québec', 'Sherbrooke', 'Montréal','Ottawa - Gatineau', 'Ottawa - Gatineau (Quebec part)','Ottawa - Gatineau (Ontario part)', 'Oshawa', 'Toronto','Hamilton', 'St. Catharines - Niagara','Kitchener - Cambridge - Waterloo', 'London', 'Windsor', 'Barrie','Winnipeg', 'Regina', 'Saskatoon', 'Calgary', 'Edmonton','Kelowna', 'Abbotsford - Mission', 'Vancouver', 'Victoria']

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"
       
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response_json = requests.get(city_url).json()
        #json.dumps(response_json, indent=4, sort_keys=True)
        #city_weather = response_json["weather"]
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json["coord"]["lat"]
        city_lng = response_json["coord"]["lon"]
        city_max_temp = response_json["main"]["temp_max"]
        city_humidity = response_json["main"]["humidity"]
        city_clouds = response_json["clouds"]["all"]
        city_wind = response_json["wind"]["speed"]
        city_country = response_json["sys"]["country"]
        city_date = response_json["dt"]
      

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | St. John's
# Processing Record 2 of Set 1 | Halifax
# Processing Record 3 of Set 1 | Québec
# Processing Record 4 of Set 1 | Sherbrooke
# Processing Record 5 of Set 1 | Montréal
# Processing Record 6 of Set 1 | Ottawa
# Processing Record 7 of Set 1 | Gatineau
# Processing Record 8 of Set 1 | Oshawa
# Processing Record 9 of Set 1 | Toronto
# Processing Record 10 of Set 1 | Hamilton
# Processing Record 11 of Set 1 | St. Catharines
# Processing Record 12 of Set 1 | Kitchener
# Processing Record 13 of Set 1 | London
# Processing Record 14 of Set 1 | Windsor
# Processing Record 15 of Set 1 | Barrie
# Processing Record 16 of Set 1 | Winnipeg
# Processing Record 17 of Set 1 | Regina
# Processing Record 18 of Set 1 | Saskatoon
# Processing Record 19 of Set 1 | Calgary
# Processing Record 20 of Set 1 | Edmonton
# Processing Record 21 of Set 1 | Kelowna
# Processing Record 22 of Set 1 | Abbotsford
# Processing Record 23 of Set 1 | Vancouver
# Processing Record 24 of Set 1 | Victoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Find out how many cities were found
len(city_data)
# Out:
# 24

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          24
# Lat           24
# Lng           24
# Max Temp      24
# Humidity      24
# Cloudiness    24
# Wind Speed    24
# Country       24
# Date          24
# dtype: int64

# %%
# Display sample data
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       St. John's  47.5649  -52.7093     -0.57        94         100
# 1          Halifax  44.6453  -63.5724      0.38        70          70
# 2           Québec  46.8123  -71.2145     -4.81        68          20
# 3       Sherbrooke  45.4001  -71.8991     -1.89        84         100
# 4         Montréal  45.5088  -73.5878      0.64        79          20
# 5           Ottawa  45.4112  -75.6981      0.16        81          20
# 6         Gatineau  45.4772  -75.7016     -0.43        82          20
# 7           Oshawa  43.9001  -78.8496      2.17        62           0
# 8          Toronto  43.7001  -79.4163      2.66        83           0
# 9         Hamilton  39.1834  -84.5333     10.52        94         100
# 10  St. Catharines  43.1668  -79.2496      1.70        86          99
# 11       Kitchener  43.4254  -80.5112      0.38        97          93
# 12          London  51.5085   -0.1257      3.50        92         100
# 13         Windsor  42.3001  -83.0165      2.34        83         100
# 14          Barrie  44.4001  -79.6663      0.57        91          99
# 15        Winnipeg  49.8844  -97.1470      0.03        91         100
# 16          Regina  50.4501 -104.6178     -4.94        76          75
# 17       Saskatoon  52.1168 -106.6345     -9.01        79          75
# 18         Calgary  51.0501 -114.0853     -2.80        76           0
# 19        Edmonton  53.5501 -113.4687     -0.56        76          20
# 20         Kelowna  49.8831 -119.4857      2.98        78           0
# 21      Abbotsford  49.0580 -122.2526      5.31        84          40
# 22       Vancouver  49.2497 -123.1193      5.60        89         100
# 23        Victoria  22.2855  114.1577     22.03        80          96
#
#     Wind Speed Country        Date
# 0         6.69      CA  1675917600
# 1         0.89      CA  1675917298
# 2         5.66      CA  1675917511
# 3         2.06      CA  1675917551
# 4         1.54      CA  1675917484
# 5         2.06      CA  1675917306
# 6         2.06      CA  1675917635
# 7         1.03      CA  1675917635
# 8         2.06      CA  1675917502
# 9         4.12      US  1675917360
# 10        2.06      CA  1675917125
# 11        1.27      CA  1675916937
# 12        1.79      GB  1675917391
# 13        2.57      CA  1675917043
# 14        0.51      CA  1675916941
# 15        8.23      CA  1675917362
# 16        7.20      CA  1675916979
# 17        2.06      CA  1675917636
# 18        2.57      CA  1675917606
# 19        3.09      CA  1675917000
# 20        1.03      CA  1675917637
# 21        3.09      CA  1675917512
# 22        4.12      CA  1675917606
# 23        7.60      HK  1675917320

# %%
city_data_df.index.name = 'City_IDWeather'
city_data_df
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_IDWeather
# 0                   St. John's  47.5649  -52.7093     -0.57        94
# 1                      Halifax  44.6453  -63.5724      0.38        70
# 2                       Québec  46.8123  -71.2145     -4.81        68
# 3                   Sherbrooke  45.4001  -71.8991     -1.89        84
# 4                     Montréal  45.5088  -73.5878      0.64        79
# 5                       Ottawa  45.4112  -75.6981      0.16        81
# 6                     Gatineau  45.4772  -75.7016     -0.43        82
# 7                       Oshawa  43.9001  -78.8496      2.17        62
# 8                      Toronto  43.7001  -79.4163      2.66        83
# 9                     Hamilton  39.1834  -84.5333     10.52        94
# 10              St. Catharines  43.1668  -79.2496      1.70        86
# 11                   Kitchener  43.4254  -80.5112      0.38        97
# 12                      London  51.5085   -0.1257      3.50        92
# 13                     Windsor  42.3001  -83.0165      2.34        83
# 14                      Barrie  44.4001  -79.6663      0.57        91
# 15                    Winnipeg  49.8844  -97.1470      0.03        91
# 16                      Regina  50.4501 -104.6178     -4.94        76
# 17                   Saskatoon  52.1168 -106.6345     -9.01        79
# 18                     Calgary  51.0501 -114.0853     -2.80        76
# 19                    Edmonton  53.5501 -113.4687     -0.56        76
# 20                     Kelowna  49.8831 -119.4857      2.98        78
# 21                  Abbotsford  49.0580 -122.2526      5.31        84
# 22                   Vancouver  49.2497 -123.1193      5.60        89
# 23                    Victoria  22.2855  114.1577     22.03        80
#
#                 Cloudiness  Wind Speed Country        Date
# City_IDWeather
# 0                      100        6.69      CA  1675917600
# 1                       70        0.89      CA  1675917298
# 2                       20        5.66      CA  1675917511
# 3                      100        2.06      CA  1675917551
# 4                       20        1.54      CA  1675917484
# 5                       20        2.06      CA  1675917306
# 6                       20        2.06      CA  1675917635
# 7                        0        1.03      CA  1675917635
# 8                        0        2.06      CA  1675917502
# 9                      100        4.12      US  1675917360
# 10                      99        2.06      CA  1675917125
# 11                      93        1.27      CA  1675916937
# 12                     100        1.79      GB  1675917391
# 13                     100        2.57      CA  1675917043
# 14                      99        0.51      CA  1675916941
# 15                     100        8.23      CA  1675917362
# 16                      75        7.20      CA  1675916979
# 17                      75        2.06      CA  1675917636
# 18                       0        2.57      CA  1675917606
# 19                      20        3.09      CA  1675917000
# 20                       0        1.03      CA  1675917637
# 21                      40        3.09      CA  1675917512
# 22                     100        4.12      CA  1675917606
# 23                      96        7.60      HK  1675917320

# %%
cities_lookup_df = pd.read_csv('Resources/cities_lookup.csv')
#, encoding='ISO-8859-1'

cities_lookup_df
# Out:
#     City_ID                              City  City_ID2  \
# 0         0                        St. John's   18372.0
# 1         1                           Halifax   18426.0
# 2         2                            Québec   18534.0
# 3         3                        Sherbrooke   18552.0
# 4         4                          Montréal   18588.0
# 5         5                 Ottawa - Gatineau   18642.0
# 6         6   Ottawa - Gatineau (Quebec part)   18606.0
# 7         7  Ottawa - Gatineau (Ontario part)   18660.0
# 8         8                            Oshawa       NaN
# 9         9                           Toronto   18732.0
# 10       10                          Hamilton   18750.0
# 11       11          St. Catharines - Niagara   18768.0
# 12       12  Kitchener - Cambridge - Waterloo   18786.0
# 13       13                            London   18840.0
# 14       14                           Windsor   18858.0
# 15       15                            Barrie   18876.0
# 16       16                          Winnipeg   18948.0
# 17       17                            Regina   18984.0
# 18       18                         Saskatoon   19002.0
# 19       19                           Calgary   19056.0
# 20       20                          Edmonton   19074.0
# 21       21                           Kelowna   19110.0
# 22       22              Abbotsford - Mission   19128.0
# 23       23                         Vancouver   19146.0
# 24       24                          Victoria   19164.0
#
#                              GEO                            Province  \
# 0                     St. John's   Newfoundland and Labrador [10001]
# 1                        Halifax                 Nova Scotia [12205]
# 2                         Québec                      Quebec [24421]
# 3                     Sherbrooke                      Quebec [24433]
# 4                       Montréal                      Quebec [24462]
# 5                Ottawa-Gatineau        Ontario/Quebec [24505/35505]
# 6                Ottawa-Gatineau                 Quebec part [24505]
# 7                Ottawa-Gatineau                Ontario part [35505]
# 8                            NaN                                 NaN
# 9                        Toronto                     Ontario [35535]
# 10                      Hamilton                     Ontario [35537]
# 11         St.Catharines-Niagara                     Ontario [35539]
# 12  Kitchener-Cambridge-Waterloo                     Ontario [35541]
# 13                        London                     Ontario [35555]
# 14                       Windsor                     Ontario [35559]
# 15                        Barrie                     Ontario [35568]
# 16                      Winnipeg                    Manitoba [46602]
# 17                        Regina                Saskatchewan [47705]
# 18                     Saskatoon                Saskatchewan [47725]
# 19                       Calgary                     Alberta [48825]
# 20                      Edmonton                     Alberta [48835]
# 21                       Kelowna            British Columbia [59915]
# 22            Abbotsford-Mission            British Columbia [59932]
# 23                     Vancouver            British Columbia [59933]
# 24                      Victoria            British Columbia [59935]
#
#     City_IDWeather    Weather_City
# 0              0.0      St. John's
# 1              1.0         Halifax
# 2              2.0          Québec
# 3              3.0      Sherbrooke
# 4              4.0        Montréal
# 5              NaN             NaN
# 6              6.0        Gatineau
# 7              5.0          Ottawa
# 8              7.0          Oshawa
# 9              8.0         Toronto
# 10             9.0        Hamilton
# 11            10.0  St. Catharines
# 12            11.0       Kitchener
# 13            12.0          London
# 14            13.0         Windsor
# 15            14.0          Barrie
# 16            15.0        Winnipeg
# 17            16.0          Regina
# 18            17.0       Saskatoon
# 19            18.0         Calgary
# 20            19.0        Edmonton
# 21            20.0         Kelowna
# 22            21.0      Abbotsford
# 23            22.0       Vancouver
# 24            23.0        Victoria

# %%
columns_to_keep = ['City_IDWeather', 'GEO', 'City_ID2']
reduced_lookup_df = cities_lookup_df[columns_to_keep]
reduced_lookup_df
# Out:
#     City_IDWeather                           GEO  City_ID2
# 0              0.0                    St. John's   18372.0
# 1              1.0                       Halifax   18426.0
# 2              2.0                        Québec   18534.0
# 3              3.0                    Sherbrooke   18552.0
# 4              4.0                      Montréal   18588.0
# 5              NaN               Ottawa-Gatineau   18642.0
# 6              6.0               Ottawa-Gatineau   18606.0
# 7              5.0               Ottawa-Gatineau   18660.0
# 8              7.0                           NaN       NaN
# 9              8.0                       Toronto   18732.0
# 10             9.0                      Hamilton   18750.0
# 11            10.0         St.Catharines-Niagara   18768.0
# 12            11.0  Kitchener-Cambridge-Waterloo   18786.0
# 13            12.0                        London   18840.0
# 14            13.0                       Windsor   18858.0
# 15            14.0                        Barrie   18876.0
# 16            15.0                      Winnipeg   18948.0
# 17            16.0                        Regina   18984.0
# 18            17.0                     Saskatoon   19002.0
# 19            18.0                       Calgary   19056.0
# 20            19.0                      Edmonton   19074.0
# 21            20.0                       Kelowna   19110.0
# 22            21.0            Abbotsford-Mission   19128.0
# 23            22.0                     Vancouver   19146.0
# 24            23.0                      Victoria   19164.0

# %%
cities_lookup_df1 = reduced_lookup_df.dropna()
cities_lookup_df1
# Out:
#     City_IDWeather                           GEO  City_ID2
# 0              0.0                    St. John's   18372.0
# 1              1.0                       Halifax   18426.0
# 2              2.0                        Québec   18534.0
# 3              3.0                    Sherbrooke   18552.0
# 4              4.0                      Montréal   18588.0
# 6              6.0               Ottawa-Gatineau   18606.0
# 7              5.0               Ottawa-Gatineau   18660.0
# 9              8.0                       Toronto   18732.0
# 10             9.0                      Hamilton   18750.0
# 11            10.0         St.Catharines-Niagara   18768.0
# 12            11.0  Kitchener-Cambridge-Waterloo   18786.0
# 13            12.0                        London   18840.0
# 14            13.0                       Windsor   18858.0
# 15            14.0                        Barrie   18876.0
# 16            15.0                      Winnipeg   18948.0
# 17            16.0                        Regina   18984.0
# 18            17.0                     Saskatoon   19002.0
# 19            18.0                       Calgary   19056.0
# 20            19.0                      Edmonton   19074.0
# 21            20.0                       Kelowna   19110.0
# 22            21.0            Abbotsford-Mission   19128.0
# 23            22.0                     Vancouver   19146.0
# 24            23.0                      Victoria   19164.0

# %%
cities_lookup_df2 = cities_lookup_df1.astype({'City_ID2':'int', 'City_IDWeather':'int'})
cities_lookup_df2
# Out:
#     City_IDWeather                           GEO  City_ID2
# 0                0                    St. John's     18372
# 1                1                       Halifax     18426
# 2                2                        Québec     18534
# 3                3                    Sherbrooke     18552
# 4                4                      Montréal     18588
# 6                6               Ottawa-Gatineau     18606
# 7                5               Ottawa-Gatineau     18660
# 9                8                       Toronto     18732
# 10               9                      Hamilton     18750
# 11              10         St.Catharines-Niagara     18768
# 12              11  Kitchener-Cambridge-Waterloo     18786
# 13              12                        London     18840
# 14              13                       Windsor     18858
# 15              14                        Barrie     18876
# 16              15                      Winnipeg     18948
# 17              16                        Regina     18984
# 18              17                     Saskatoon     19002
# 19              18                       Calgary     19056
# 20              19                      Edmonton     19074
# 21              20                       Kelowna     19110
# 22              21            Abbotsford-Mission     19128
# 23              22                     Vancouver     19146
# 24              23                      Victoria     19164

# %%
merged_df = city_data_df.merge(cities_lookup_df2, on='City_IDWeather', how='inner')
merged_df
# Out:
#     City_IDWeather            City      Lat       Lng  Max Temp  Humidity  \
# 0                0      St. John's  47.5649  -52.7093     -0.57        94
# 1                1         Halifax  44.6453  -63.5724      0.38        70
# 2                2          Québec  46.8123  -71.2145     -4.81        68
# 3                3      Sherbrooke  45.4001  -71.8991     -1.89        84
# 4                4        Montréal  45.5088  -73.5878      0.64        79
# 5                5          Ottawa  45.4112  -75.6981      0.16        81
# 6                6        Gatineau  45.4772  -75.7016     -0.43        82
# 7                8         Toronto  43.7001  -79.4163      2.66        83
# 8                9        Hamilton  39.1834  -84.5333     10.52        94
# 9               10  St. Catharines  43.1668  -79.2496      1.70        86
# 10              11       Kitchener  43.4254  -80.5112      0.38        97
# 11              12          London  51.5085   -0.1257      3.50        92
# 12              13         Windsor  42.3001  -83.0165      2.34        83
# 13              14          Barrie  44.4001  -79.6663      0.57        91
# 14              15        Winnipeg  49.8844  -97.1470      0.03        91
# 15              16          Regina  50.4501 -104.6178     -4.94        76
# 16              17       Saskatoon  52.1168 -106.6345     -9.01        79
# 17              18         Calgary  51.0501 -114.0853     -2.80        76
# 18              19        Edmonton  53.5501 -113.4687     -0.56        76
# 19              20         Kelowna  49.8831 -119.4857      2.98        78
# 20              21      Abbotsford  49.0580 -122.2526      5.31        84
# 21              22       Vancouver  49.2497 -123.1193      5.60        89
# 22              23        Victoria  22.2855  114.1577     22.03        80
#
#     Cloudiness  Wind Speed Country        Date                           GEO  \
# 0          100        6.69      CA  1675917600                    St. John's
# 1           70        0.89      CA  1675917298                       Halifax
# 2           20        5.66      CA  1675917511                        Québec
# 3          100        2.06      CA  1675917551                    Sherbrooke
# 4           20        1.54      CA  1675917484                      Montréal
# 5           20        2.06      CA  1675917306               Ottawa-Gatineau
# 6           20        2.06      CA  1675917635               Ottawa-Gatineau
# 7            0        2.06      CA  1675917502                       Toronto
# 8          100        4.12      US  1675917360                      Hamilton
# 9           99        2.06      CA  1675917125         St.Catharines-Niagara
# 10          93        1.27      CA  1675916937  Kitchener-Cambridge-Waterloo
# 11         100        1.79      GB  1675917391                        London
# 12         100        2.57      CA  1675917043                       Windsor
# 13          99        0.51      CA  1675916941                        Barrie
# 14         100        8.23      CA  1675917362                      Winnipeg
# 15          75        7.20      CA  1675916979                        Regina
# 16          75        2.06      CA  1675917636                     Saskatoon
# 17           0        2.57      CA  1675917606                       Calgary
# 18          20        3.09      CA  1675917000                      Edmonton
# 19           0        1.03      CA  1675917637                       Kelowna
# 20          40        3.09      CA  1675917512            Abbotsford-Mission
# 21         100        4.12      CA  1675917606                     Vancouver
# 22          96        7.60      HK  1675917320                      Victoria
#
#     City_ID2
# 0      18372
# 1      18426
# 2      18534
# 3      18552
# 4      18588
# 5      18660
# 6      18606
# 7      18732
# 8      18750
# 9      18768
# 10     18786
# 11     18840
# 12     18858
# 13     18876
# 14     18948
# 15     18984
# 16     19002
# 17     19056
# 18     19074
# 19     19110
# 20     19128
# 21     19146
# 22     19164

# %%
len(merged_df)
# Out:
# 23
