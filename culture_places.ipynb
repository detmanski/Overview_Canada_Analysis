# %%
import hvplot.pandas
import pandas as pd
import requests
from api_keys import geoapify_key
import os
import json
from pprint import pprint

# %%
culture_vis_df = pd.read_csv("Resources/culture_vis_df.csv")
culture_vis_df
# Out:
#    Unnamed: 0          Province  Making Music(%)  Theatre(%)  \
# 0           0  British Columbia             15.8         0.0
# 1           1           Alberta             12.3         0.0
# 2           2          Manitoba             17.2         0.0
# 3           3           Ontario             15.8         1.9
# 4           4            Quebec             11.6         0.0
# 5           5       Nova Scotia             17.9         0.0
#
#    Audio-Visual and Interactive Media(%)  Dancing(%)  Visual Arts(%)  \
# 0                                    4.5         9.8            14.8
# 1                                    4.0        10.2            13.5
# 2                                    0.0         7.4            11.4
# 3                                    5.4        10.1            14.9
# 4                                    2.6         7.1             8.5
# 5                                    4.3         7.7            15.0
#
# ...

# %%
condensed_df = pd.read_csv("Resources/condensed_culture_df.csv")
condensed_df
# Out:
#     Unnamed: 0            Name  Participation in Cultural Activities (%)
# 0            0         Halifax                                      60.9
# 1            1          Québec                                      40.3
# 2            2        Montréal                                      40.3
# 3            3        Gatineau                                      40.3
# 4            4          Ottawa                                      54.8
# 5            5         Toronto                                      54.8
# 6            6        Hamilton                                      54.8
# 7            7  St. Catherines                                      54.8
# 8            8       Kitchener                                      54.8
# 9            9          London                                      54.8
# 10          10         Windsor                                      54.8
# 11          11        Winnipeg                                      52.7
# ...

# %%
condensed_df.insert(3, "Places", "")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mc/ktgbqxj54dd2hpjj2g0t7x4c0000gn/T/ipykernel_48794/1158911671.py in <module>
# ----> 1 condensed_df.insert(3, "Places", "")
#       2 condensed_df.insert(2, "Country", "CA")
#       3 condensed_df
#
# ~/opt/anaconda3/envs/pythondata/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# ~/opt/anaconda3/envs/pythondata/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
# ...

# %%
condensed_df.insert(2, "Country", "CA")
condensed_df
# Out:
#     Unnamed: 0            Name Country  \
# 0            0         Halifax      CA
# 1            1          Québec      CA
# 2            2        Montréal      CA
# 3            3        Gatineau      CA
# 4            4          Ottawa      CA
# 5            5         Toronto      CA
# 6            6        Hamilton      CA
# 7            7  St. Catherines      CA
# 8            8       Kitchener      CA
# 9            9          London      CA
# 10          10         Windsor      CA
# 11          11        Winnipeg      CA
# 12          12         Calgary      CA
# 13          13        Edmonton      CA
# 14          14       Vancouver      CA
#
#     Participation in Cultural Activities (%)
# 0                                       60.9
# 1                                       40.3
# 2                                       40.3
# 3                                       40.3
# 4                                       54.8
# 5                                       54.8
# ...

# %%
del(condensed_df["Lng"])

# %%
condensed_df.insert(3, "Lat", [44.6453, 46.8123, 45.5088, 45.4772, 45.4112, 43.7001, 43.2334, 43.1668, 43.4214, 42.9834, 42.3001, 49.8844, 51.0501, 53.5501, 49.2497
                              ])

# %%
condensed_df.insert(4, "Lng", [-63.5724, -71.2145, -73.5878, -75.7016, -75.6981, -79.4163, -79.9496, -79.2496, -80.5112, -81.2330, -83.0165, -97.1470, -114.0853, -113.4687, -123.1193])

# %%
condensed_df
# Out:
#     Unnamed: 0            Name Country      Lat       Lng  \
# 0            0         Halifax      CA  44.6453  -63.5724
# 1            1          Québec      CA  46.8123  -71.2145
# 2            2        Montréal      CA  45.5088  -73.5878
# 3            3        Gatineau      CA  45.4772  -75.7016
# 4            4          Ottawa      CA  45.4112  -75.6981
# 5            5         Toronto      CA  43.7001  -79.4163
# 6            6        Hamilton      CA  43.2334  -79.9496
# 7            7  St. Catherines      CA  43.1668  -79.2496
# 8            8       Kitchener      CA  43.4214  -80.5112
# 9            9          London      CA  42.9834  -81.2330
# 10          10         Windsor      CA  42.3001  -83.0165
# 11          11        Winnipeg      CA  49.8844  -97.1470
# 12          12         Calgary      CA  51.0501 -114.0853
# 13          13        Edmonton      CA  53.5501 -113.4687
# 14          14       Vancouver      CA  49.2497 -123.1193
#
# ...

# %%
radius = 50000
params = {
    "categories":"entertainment.culture",
    "apiKey": geoapify_key,
    "limit":20
}


print("Starting culture details search")


for index, row in condensed_df.iterrows():
    
   
    city = row["Name"]
    
    
    latitude = row["Lat"]
    longitude = row["Lng"]
    

    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    
    
    
    base_url = "https://api.geoapify.com/v2/places"
           
    
    response = requests.get(base_url, params=params)
        
   
    response = response.json()
    try:
        for place in city: response["features"][0]['properties']['address_line1']
    except (KeyError, IndexError):
            no_place = "no places found"
    
    print(f"{city} - nearest place: {place}")
# Out:
# Starting culture details search
# Halifax - nearest place: x
# Québec - nearest place: c
# Montréal - nearest place: l
# Gatineau - nearest place: u
# Ottawa - nearest place: a
# Toronto - nearest place: o
# Hamilton - nearest place: n
# St. Catherines - nearest place: s
# Kitchener - nearest place: r
# London - nearest place: n
# Windsor - nearest place: r
# Winnipeg - nearest place: g
# Calgary - nearest place: y
# Edmonton - nearest place: n
# Vancouver - nearest place: r

# %%
condensed_df
# Out:
#     Unnamed: 0            Name Country      Lat       Lng  \
# 0            0         Halifax      CA  44.6453  -63.5724
# 1            1          Québec      CA  46.8123  -71.2145
# 2            2        Montréal      CA  45.5088  -73.5878
# 3            3        Gatineau      CA  45.4772  -75.7016
# 4            4          Ottawa      CA  45.4112  -75.6981
# 5            5         Toronto      CA  43.7001  -79.4163
# 6            6        Hamilton      CA  43.2334  -79.9496
# 7            7  St. Catherines      CA  43.1668  -79.2496
# 8            8       Kitchener      CA  43.4214  -80.5112
# 9            9          London      CA  42.9834  -81.2330
# 10          10         Windsor      CA  42.3001  -83.0165
# 11          11        Winnipeg      CA  49.8844  -97.1470
# 12          12         Calgary      CA  51.0501 -114.0853
# 13          13        Edmonton      CA  53.5501 -113.4687
# 14          14       Vancouver      CA  49.2497 -123.1193
#
# ...

# %%
radius = 50000
params = {
    "categories":"entertainment.culture",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the airport search
print("Starting culture details search")

# Iterate through the types_df DataFrame
for index, row in condensed_df.iterrows():
    
    # Get the city's name
    city = row["Name"]
    
    # Get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
           
    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)
        
    # Convert the API response to JSON format
    response = response.json()
    try:
        condensed_df.loc[index, "Places"] = response["features"][0]['properties']['address_line1']
    except (KeyError, IndexError):
            condensed_df.loc[index, 'Places'] = "no places found"
    
    print(f"{condensed_df.loc[index, 'Name']} - nearest place: {condensed_df.loc[index, 'Places']}")
