# %%
import os
import pandas as pd

# %%
bc_string = 'Resources/BC_Cultural_Participation.csv'
bc_df = pd.read_csv(bc_string)
bc_df.head()
# Out:
#    REF_DATE               GEO        DGUID                 Age group  \
# 0      2016  British Columbia  2016A000259  Total, 15 years and over
# 1      2016  British Columbia  2016A000259  Total, 15 years and over
# 2      2016  British Columbia  2016A000259  Total, 15 years and over
# 3      2016  British Columbia  2016A000259  Total, 15 years and over
# 4      2016  British Columbia  2016A000259  Total, 15 years and over
#
#           Sex         Current employment status         Perceived health  \
# 0  Both sexes  Total, current employment status  Total, perceived health
# 1  Both sexes  Total, current employment status  Total, perceived health
# 2  Both sexes  Total, current employment status  Total, perceived health
# 3  Both sexes  Total, current employment status  Total, perceived health
# 4  Both sexes  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# ...

# %%
bc_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
bc_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
bc_df
# Out:
#                  GEO                         Cultural activities  \
# 0   British Columbia                                Making music
# 1   British Columbia                                Making music
# 2   British Columbia                                     Theatre
# 3   British Columbia                                     Theatre
# 4   British Columbia          Audio-visual and interactive media
# 5   British Columbia          Audio-visual and interactive media
# 6   British Columbia                                     Dancing
# 7   British Columbia                                     Dancing
# 8   British Columbia                                 Visual arts
# 9   British Columbia                                 Visual arts
# 10  British Columbia                                    Crafting
# 11  British Columbia                                    Crafting
# 12  British Columbia                                     Writing
# ...

# %%
mb_string = 'Resources/MB_Cultural_Participation.csv'
mb_df = pd.read_csv(mb_string)
mb_df.head()
# Out:
#    REF_DATE       GEO           DGUID                 Age group         Sex  \
# 0      2016  Manitoba  2016A000011124  Total, 15 years and over  Both sexes
# 1      2016  Manitoba  2016A000011124  Total, 15 years and over  Both sexes
# 2      2016  Manitoba  2016A000011124  Total, 15 years and over  Both sexes
# 3      2016  Manitoba  2016A000011124  Total, 15 years and over  Both sexes
# 4      2016  Manitoba  2016A000011124  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# ...

# %%
mb_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
mb_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
mb_df
# Out:
#          GEO                         Cultural activities  \
# 0   Manitoba                                Making music
# 1   Manitoba                                Making music
# 2   Manitoba                                     Theatre
# 3   Manitoba                                     Theatre
# 4   Manitoba          Audio-visual and interactive media
# 5   Manitoba          Audio-visual and interactive media
# 6   Manitoba                                     Dancing
# 7   Manitoba                                     Dancing
# 8   Manitoba                                 Visual arts
# 9   Manitoba                                 Visual arts
# 10  Manitoba                                    Crafting
# 11  Manitoba                                    Crafting
# 12  Manitoba                                     Writing
# 13  Manitoba                                     Writing
# 14  Manitoba                   Other cultural activities
# ...

# %%
nb_string = 'Resources/NB_Cultural_Participation.csv'
nb_df = pd.read_csv(nb_string)
nb_df.head()
# Out:
#    REF_DATE            GEO        DGUID                 Age group         Sex  \
# 0      2016  New Brunswick  2016A000213  Total, 15 years and over  Both sexes
# 1      2016  New Brunswick  2016A000213  Total, 15 years and over  Both sexes
# 2      2016  New Brunswick  2016A000213  Total, 15 years and over  Both sexes
# 3      2016  New Brunswick  2016A000213  Total, 15 years and over  Both sexes
# 4      2016  New Brunswick  2016A000213  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# ...

# %%
nb_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
nb_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
nb_df
# Out:
#               GEO                         Cultural activities  \
# 0   New Brunswick                                Making music
# 1   New Brunswick                                Making music
# 2   New Brunswick                                     Theatre
# 3   New Brunswick                                     Theatre
# 4   New Brunswick          Audio-visual and interactive media
# 5   New Brunswick          Audio-visual and interactive media
# 6   New Brunswick                                     Dancing
# 7   New Brunswick                                     Dancing
# 8   New Brunswick                                 Visual arts
# 9   New Brunswick                                 Visual arts
# 10  New Brunswick                                    Crafting
# 11  New Brunswick                                    Crafting
# 12  New Brunswick                                     Writing
# 13  New Brunswick                                     Writing
# ...

# %%
nl_string = 'Resources/NL_Cultural_Participation.csv'
nl_df = pd.read_csv(nl_string)
nl_df.head()
# Out:
#    REF_DATE                        GEO        DGUID                 Age group  \
# 0      2016  Newfoundland and Labrador  2016A000210  Total, 15 years and over
# 1      2016  Newfoundland and Labrador  2016A000210  Total, 15 years and over
# 2      2016  Newfoundland and Labrador  2016A000210  Total, 15 years and over
# 3      2016  Newfoundland and Labrador  2016A000210  Total, 15 years and over
# 4      2016  Newfoundland and Labrador  2016A000210  Total, 15 years and over
#
#           Sex         Current employment status         Perceived health  \
# 0  Both sexes  Total, current employment status  Total, perceived health
# 1  Both sexes  Total, current employment status  Total, perceived health
# 2  Both sexes  Total, current employment status  Total, perceived health
# 3  Both sexes  Total, current employment status  Total, perceived health
# 4  Both sexes  Total, current employment status  Total, perceived health
#
# ...

# %%
nl_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
nl_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
nl_df
# Out:
#                           GEO                         Cultural activities  \
# 0   Newfoundland and Labrador                                Making music
# 1   Newfoundland and Labrador                                Making music
# 2   Newfoundland and Labrador                                     Theatre
# 3   Newfoundland and Labrador                                     Theatre
# 4   Newfoundland and Labrador          Audio-visual and interactive media
# 5   Newfoundland and Labrador          Audio-visual and interactive media
# 6   Newfoundland and Labrador                                     Dancing
# 7   Newfoundland and Labrador                                     Dancing
# 8   Newfoundland and Labrador                                 Visual arts
# 9   Newfoundland and Labrador                                 Visual arts
# 10  Newfoundland and Labrador                                    Crafting
# 11  Newfoundland and Labrador                                    Crafting
# ...

# %%
ab_string = 'Resources/AB_Cultural_Participation.csv'
ab_df = pd.read_csv(ab_string)
ab_df.head()
# Out:
#    REF_DATE      GEO        DGUID                 Age group         Sex  \
# 0      2016  Alberta  2016A000248  Total, 15 years and over  Both sexes
# 1      2016  Alberta  2016A000248  Total, 15 years and over  Both sexes
# 2      2016  Alberta  2016A000248  Total, 15 years and over  Both sexes
# 3      2016  Alberta  2016A000248  Total, 15 years and over  Both sexes
# 4      2016  Alberta  2016A000248  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# 0                        Making music      Number of persons  Persons   427.0
# ...

# %%
ab_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
ab_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
ab_df
# Out:
#         GEO                         Cultural activities  \
# 0   Alberta                                Making music
# 1   Alberta                                Making music
# 2   Alberta                                     Theatre
# 3   Alberta                                     Theatre
# 4   Alberta          Audio-visual and interactive media
# 5   Alberta          Audio-visual and interactive media
# 6   Alberta                                     Dancing
# 7   Alberta                                     Dancing
# 8   Alberta                                 Visual arts
# 9   Alberta                                 Visual arts
# 10  Alberta                                    Crafting
# 11  Alberta                                    Crafting
# 12  Alberta                                     Writing
# 13  Alberta                                     Writing
# 14  Alberta                   Other cultural activities
# 15  Alberta                   Other cultural activities
# ...

# %%
ns_string = 'Resources/NS_Cultural_Participation.csv'
ns_df = pd.read_csv(ns_string)
ns_df.head()
# Out:
#    REF_DATE          GEO        DGUID                 Age group         Sex  \
# 0      2016  Nova Scotia  2016A000212  Total, 15 years and over  Both sexes
# 1      2016  Nova Scotia  2016A000212  Total, 15 years and over  Both sexes
# 2      2016  Nova Scotia  2016A000212  Total, 15 years and over  Both sexes
# 3      2016  Nova Scotia  2016A000212  Total, 15 years and over  Both sexes
# 4      2016  Nova Scotia  2016A000212  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# ...

# %%
ns_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
ns_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
ns_df
# Out:
#             GEO                         Cultural activities  \
# 0   Nova Scotia                                Making music
# 1   Nova Scotia                                Making music
# 2   Nova Scotia                                     Theatre
# 3   Nova Scotia                                     Theatre
# 4   Nova Scotia          Audio-visual and interactive media
# 5   Nova Scotia          Audio-visual and interactive media
# 6   Nova Scotia                                     Dancing
# 7   Nova Scotia                                     Dancing
# 8   Nova Scotia                                 Visual arts
# 9   Nova Scotia                                 Visual arts
# 10  Nova Scotia                                    Crafting
# 11  Nova Scotia                                    Crafting
# 12  Nova Scotia                                     Writing
# 13  Nova Scotia                                     Writing
# 14  Nova Scotia                   Other cultural activities
# ...

# %%
on_string = 'Resources/ON_Cultural_Participation.csv'
on_df = pd.read_csv(on_string)
on_df.head()
# Out:
#    REF_DATE      GEO        DGUID                 Age group         Sex  \
# 0      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 1      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 2      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 3      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
# 4      2016  Ontario  2016A000235  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# 0                        Making music      Number of persons  Persons  1847.0
# ...

# %%
on_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
on_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
on_df
# Out:
#         GEO                         Cultural activities  \
# 0   Ontario                                Making music
# 1   Ontario                                Making music
# 2   Ontario                                     Theatre
# 3   Ontario                                     Theatre
# 4   Ontario          Audio-visual and interactive media
# 5   Ontario          Audio-visual and interactive media
# 6   Ontario                                     Dancing
# 7   Ontario                                     Dancing
# 8   Ontario                                 Visual arts
# 9   Ontario                                 Visual arts
# 10  Ontario                                    Crafting
# 11  Ontario                                    Crafting
# 12  Ontario                                     Writing
# 13  Ontario                                     Writing
# 14  Ontario                   Other cultural activities
# 15  Ontario                   Other cultural activities
# ...

# %%
pe_string = 'Resources/PE_Cultural_Participation.csv'
pe_df = pd.read_csv(pe_string)
pe_df.head()
# Out:
#    REF_DATE                   GEO        DGUID                 Age group  \
# 0      2016  Prince Edward Island  2016A000211  Total, 15 years and over
# 1      2016  Prince Edward Island  2016A000211  Total, 15 years and over
# 2      2016  Prince Edward Island  2016A000211  Total, 15 years and over
# 3      2016  Prince Edward Island  2016A000211  Total, 15 years and over
# 4      2016  Prince Edward Island  2016A000211  Total, 15 years and over
#
#           Sex         Current employment status         Perceived health  \
# 0  Both sexes  Total, current employment status  Total, perceived health
# 1  Both sexes  Total, current employment status  Total, perceived health
# 2  Both sexes  Total, current employment status  Total, perceived health
# 3  Both sexes  Total, current employment status  Total, perceived health
# 4  Both sexes  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# ...

# %%
pe_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
pe_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
pe_df
# Out:
#                      GEO                         Cultural activities  \
# 0   Prince Edward Island                                Making music
# 1   Prince Edward Island                                Making music
# 2   Prince Edward Island                                     Theatre
# 3   Prince Edward Island                                     Theatre
# 4   Prince Edward Island          Audio-visual and interactive media
# 5   Prince Edward Island          Audio-visual and interactive media
# 6   Prince Edward Island                                     Dancing
# 7   Prince Edward Island                                     Dancing
# 8   Prince Edward Island                                 Visual arts
# 9   Prince Edward Island                                 Visual arts
# 10  Prince Edward Island                                    Crafting
# 11  Prince Edward Island                                    Crafting
# 12  Prince Edward Island                                     Writing
# ...

# %%
qc_string = 'Resources/QC_Cultural_Participation.csv'
qc_df = pd.read_csv(qc_string)
qc_df.head()
# Out:
#    REF_DATE     GEO        DGUID                 Age group         Sex  \
# 0      2016  Quebec  2016A000224  Total, 15 years and over  Both sexes
# 1      2016  Quebec  2016A000224  Total, 15 years and over  Both sexes
# 2      2016  Quebec  2016A000224  Total, 15 years and over  Both sexes
# 3      2016  Quebec  2016A000224  Total, 15 years and over  Both sexes
# 4      2016  Quebec  2016A000224  Total, 15 years and over  Both sexes
#
#           Current employment status         Perceived health  \
# 0  Total, current employment status  Total, perceived health
# 1  Total, current employment status  Total, perceived health
# 2  Total, current employment status  Total, perceived health
# 3  Total, current employment status  Total, perceived health
# 4  Total, current employment status  Total, perceived health
#
#                   Cultural activities              Estimates      UOM  UOM_ID  \
# 0                        Making music      Number of persons  Persons   807.0
# ...

# %%
qc_df.drop(columns=["REF_DATE","DGUID","Age group","Sex","Current employment status", "Perceived health", "VECTOR", "COORDINATE"], inplace=True)
qc_df.drop(columns=["VALUE", "STATUS", "SYMBOL", "TERMINATED", "DECIMALS"], inplace=True)
qc_df
# Out:
#        GEO                         Cultural activities              Estimates  \
# 0   Quebec                                Making music      Number of persons
# 1   Quebec                                Making music  Percentage of persons
# 2   Quebec                                     Theatre      Number of persons
# 3   Quebec                                     Theatre  Percentage of persons
# 4   Quebec          Audio-visual and interactive media      Number of persons
# 5   Quebec          Audio-visual and interactive media  Percentage of persons
# 6   Quebec                                     Dancing      Number of persons
# 7   Quebec                                     Dancing  Percentage of persons
# 8   Quebec                                 Visual arts      Number of persons
# 9   Quebec                                 Visual arts  Percentage of persons
# 10  Quebec                                    Crafting      Number of persons
# ...
