# %%
import pandas as pd

# %% [markdown]
# ## Questions
#     - Q1
#     - Q2
#     - Q3
#     - Q4
#     - Q5

# %% [markdown]
# You need the encoding line due to French characters

# %%
df = pd.read_csv('Resources/98-401-X2021002_English_CSV_data.csv', encoding='ISO-8859-1')


df.head()
# Out:
#    CENSUS_YEAR         DGUID  ALT_GEO_CODE                 GEO_LEVEL  \
# 0         2021  2021S0503001             1  Census metropolitan area
# 1         2021  2021S0503001             1  Census metropolitan area
# 2         2021  2021S0503001             1  Census metropolitan area
# 3         2021  2021S0503001             1  Census metropolitan area
# 4         2021  2021S0503001             1  Census metropolitan area
#
#      GEO_NAME  TNR_SF  TNR_LF  DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# 0  St. John's     2.9     4.1                  0                  1
# 1  St. John's     2.9     4.1                  0                  2
# 2  St. John's     2.9     4.1                  0                  3
# 3  St. John's     2.9     4.1                  0                  4
# 4  St. John's     2.9     4.1                  0                  5
#
#                              CHARACTERISTIC_NAME  ...  C2_COUNT_MEN+  \
# 0                               Population, 2021  ...            NaN
# 1                               Population, 2016  ...            NaN
# 2     Population percentage change, 2016 to 2021  ...            NaN
# 3                        Total private dwellings  ...            NaN
# 4  Private dwellings occupied by usual residents  ...            NaN
#
#    SYMBOL.1 C3_COUNT_WOMEN+  SYMBOL.2 C10_RATE_TOTAL  SYMBOL.3 C11_RATE_MEN+  \
# 0       ...             NaN       ...            NaN       ...           NaN
# 1       ...             NaN       ...            NaN       ...           NaN
# 2       ...             NaN       ...            2.0       NaN           NaN
# 3       ...             NaN       ...            NaN       ...           NaN
# 4       ...             NaN       ...            NaN       ...           NaN
#
#    SYMBOL.4 C12_RATE_WOMEN+  SYMBOL.5
# 0       ...             NaN       ...
# 1       ...             NaN       ...
# 2       ...             NaN       ...
# 3       ...             NaN       ...
# 4       ...             NaN       ...
#
# [5 rows x 23 columns]

# %%
columns_to_keep=['GEO_NAME','CHARACTERISTIC_ID','CHARACTERISTIC_NAME','C1_COUNT_TOTAL']
reduced_df=df[columns_to_keep]

# %%
#cut down columns for readability
reduced_df.head()
# Out:
#      GEO_NAME  CHARACTERISTIC_ID  \
# 0  St. John's                  1
# 1  St. John's                  2
# 2  St. John's                  3
# 3  St. John's                  4
# 4  St. John's                  5
#
#                              CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 0                               Population, 2021        212579.0
# 1                               Population, 2016        208418.0
# 2     Population percentage change, 2016 to 2021             2.0
# 3                        Total private dwellings         97429.0
# 4  Private dwellings occupied by usual residents         89999.0

# %% [markdown]
# # So, this is the 2021 census data for the entirety of Canada.
#     - GEO_NAME refers to the province/territory or you can use Canada to get the grand total.
#     - If you look at the 98-401...meta.txt there's a portion that has CHARACTERISTIC_ID and the corresponding statistic which is stored in CHARACTERISTIC_NAME.  There are...a lot.

# %% [markdown]
# So, I just did a little test below after looking at some of the CHARACTERISTIC_ID and filtered the ones <= 7 which is population info.

# %%
filtered_df = reduced_df[reduced_df['CHARACTERISTIC_ID'] <= 7]

# %%
filtered_df.head(7)
# Out:
#      GEO_NAME  CHARACTERISTIC_ID  \
# 0  St. John's                  1
# 1  St. John's                  2
# 2  St. John's                  3
# 3  St. John's                  4
# 4  St. John's                  5
# 5  St. John's                  6
# 6  St. John's                  7
#
#                              CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 0                               Population, 2021       212579.00
# 1                               Population, 2016       208418.00
# 2     Population percentage change, 2016 to 2021            2.00
# 3                        Total private dwellings        97429.00
# 4  Private dwellings occupied by usual residents        89999.00
# 5        Population density per square kilometre          228.20
# 6                 Land area in square kilometres          931.56

# %%
group_df=filtered_df.groupby(['GEO_NAME','CHARACTERISTIC_NAME'])['C1_COUNT_TOTAL'].sum()

# %%
group_df['Toronto']
# Out:
# CHARACTERISTIC_NAME
# Land area in square kilometres                      5902.75
# Population density per square kilometre             1050.70
# Population percentage change, 2016 to 2021             4.60
# Population, 2016                                 5928040.00
# Population, 2021                                 6202225.00
# Private dwellings occupied by usual residents    2262473.00
# Total private dwellings                          2394205.00
# Name: C1_COUNT_TOTAL, dtype: float64

# %%
pop_df = filtered_df[filtered_df['CHARACTERISTIC_ID']==1]

# %%
pop_df.head()
# Out:
#                   GEO_NAME  CHARACTERISTIC_ID CHARACTERISTIC_NAME  \
# 0               St. John's                  1    Population, 2021
# 2631   Grand Falls-Windsor                  1    Population, 2021
# 5262                Gander                  1    Population, 2021
# 7893          Corner Brook                  1    Population, 2021
# 10524        Charlottetown                  1    Population, 2021
#
#        C1_COUNT_TOTAL
# 0            212579.0
# 2631          13853.0
# 5262          13414.0
# 7893          29762.0
# 10524         78858.0

# %%
pop_group=pop_df.groupby(['GEO_NAME','CHARACTERISTIC_NAME'])

# %% [markdown]
# ## Top 15 Cities by Population

# %%
pop_group['C1_COUNT_TOTAL'].max().sort_values(ascending=False).head(15)
# Out:
# GEO_NAME                          CHARACTERISTIC_NAME
# Toronto                           Population, 2021       6202225.0
# Montréal                          Population, 2021       4291732.0
# Vancouver                         Population, 2021       2642825.0
# Ottawa - Gatineau                 Population, 2021       1488307.0
# Calgary                           Population, 2021       1481806.0
# Edmonton                          Population, 2021       1418118.0
# Ottawa - Gatineau (Ontario part)  Population, 2021       1135014.0
# Québec                            Population, 2021        839311.0
# Winnipeg                          Population, 2021        834678.0
# Hamilton                          Population, 2021        785184.0
# Kitchener - Cambridge - Waterloo  Population, 2021        575847.0
# London                            Population, 2021        543551.0
# Halifax                           Population, 2021        465703.0
# St. Catharines - Niagara          Population, 2021        433604.0
# Windsor                           Population, 2021        422630.0
# Name: C1_COUNT_TOTAL, dtype: float64

# %%
top_15_cities = pop_group['C1_COUNT_TOTAL'].max().sort_values(ascending=False).head(15)
top_15_cities = top_15_cities.index.get_level_values(0)
mask = reduced_df['GEO_NAME'].isin(top_15_cities)
top_15_pop_df = reduced_df[mask]

# %%
top_15_pop_df.head()
# Out:
#       GEO_NAME  CHARACTERISTIC_ID  \
# 15786  Halifax                  1
# 15787  Halifax                  2
# 15788  Halifax                  3
# 15789  Halifax                  4
# 15790  Halifax                  5
#
#                                  CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 15786                               Population, 2021        465703.0
# 15787                               Population, 2016        426932.0
# 15788     Population percentage change, 2016 to 2021             9.1
# 15789                        Total private dwellings        211789.0
# 15790  Private dwellings occupied by usual residents        201138.0

# %%
#income = top_25_pop_df[(top_25_pop_df['CHARACTERISTIC_ID'] == 119) & (top_25_pop_df['CHARACTERISTIC_ID'] == 134)]

# %% [markdown]
# ## Median and Average Income for Top 25 Cities

# %%
median_income = top_15_pop_df[top_15_pop_df['CHARACTERISTIC_ID'] == 119]

# %%
average_income = top_15_pop_df[top_15_pop_df['CHARACTERISTIC_ID'] == 134]

# %%
median_graph = median_income.plot(kind='bar',x='GEO_NAME',y='C1_COUNT_TOTAL')

median_graph.set_ylabel('Income($)')
median_graph.set_title('Median Income by City')
# Out:
# Text(0.5, 1.0, 'Median Income by City')

# %%
average_graph = average_income.plot(kind='bar',x='GEO_NAME',y='C1_COUNT_TOTAL')

average_graph.set_ylabel('Income($)')
average_graph.set_title('Average Income by City')
# Out:
# Text(0.5, 1.0, 'Average Income by City')

# %% [markdown]
# ## Employment Rate

# %%
emp_rate_df = top_15_pop_df[top_15_pop_df['CHARACTERISTIC_ID'] == 2229]
emp_rate_df
# Out:
#                                 GEO_NAME  CHARACTERISTIC_ID  \
# 18014                            Halifax               2229
# 75896                             Québec               2229
# 112730                          Montréal               2229
# 141671                 Ottawa - Gatineau               2229
# 146933  Ottawa - Gatineau (Ontario part)               2229
# 181136                           Toronto               2229
# 183767                          Hamilton               2229
# 186398          St. Catharines - Niagara               2229
# 189029  Kitchener - Cambridge - Waterloo               2229
# 207446                            London               2229
# 212708                           Windsor               2229
# 254804                          Winnipeg               2229
# 307424                           Calgary               2229
# 325841                          Edmonton               2229
# 370568                         Vancouver               2229
#
#        CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 18014      Employment rate            58.0
# 75896      Employment rate            62.0
# 112730     Employment rate            60.7
# 141671     Employment rate            59.6
# 146933     Employment rate            59.2
# 181136     Employment rate            56.1
# 183767     Employment rate            55.3
# 186398     Employment rate            48.6
# 189029     Employment rate            59.2
# 207446     Employment rate            54.4
# 212708     Employment rate            49.5
# 254804     Employment rate            60.3
# 307424     Employment rate            60.8
# 325841     Employment rate            60.0
# 370568     Employment rate            60.0

# %%
employment_graph = emp_rate_df.plot(kind='bar',x='GEO_NAME',y='C1_COUNT_TOTAL')
employment_graph

# %% [markdown]
# ## Crime

# %% [markdown]
# ## Weather

# %% [markdown]
# ## Cultural Activity

# %% [markdown]
# ## Shelter Cost

# %%
## Median monthly shelter costs for owned dwellings 
med_owned_shelter_cost = top_15_pop_df[top_15_pop_df['CHARACTERISTIC_ID'] == 1486]
med_owned_shelter_cost
# Out:
#                                 GEO_NAME  CHARACTERISTIC_ID  \
# 17271                            Halifax               1486
# 75153                             Québec               1486
# 111987                          Montréal               1486
# 140928                 Ottawa - Gatineau               1486
# 146190  Ottawa - Gatineau (Ontario part)               1486
# 180393                           Toronto               1486
# 183024                          Hamilton               1486
# 185655          St. Catharines - Niagara               1486
# 188286  Kitchener - Cambridge - Waterloo               1486
# 206703                            London               1486
# 211965                           Windsor               1486
# 254061                          Winnipeg               1486
# 306681                           Calgary               1486
# 325098                          Edmonton               1486
# 369825                         Vancouver               1486
#
#                                       CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 17271     Median monthly shelter costs for owned dwell...          1270.0
# 75153     Median monthly shelter costs for owned dwell...          1140.0
# 111987    Median monthly shelter costs for owned dwell...          1310.0
# 140928    Median monthly shelter costs for owned dwell...          1440.0
# 146190    Median monthly shelter costs for owned dwell...          1550.0
# 180393    Median monthly shelter costs for owned dwell...          1900.0
# 183024    Median monthly shelter costs for owned dwell...          1500.0
# 185655    Median monthly shelter costs for owned dwell...          1130.0
# 188286    Median monthly shelter costs for owned dwell...          1540.0
# 206703    Median monthly shelter costs for owned dwell...          1240.0
# 211965    Median monthly shelter costs for owned dwell...          1070.0
# 254061    Median monthly shelter costs for owned dwell...          1250.0
# 306681    Median monthly shelter costs for owned dwell...          1740.0
# 325098    Median monthly shelter costs for owned dwell...          1700.0
# 369825    Median monthly shelter costs for owned dwell...          1620.0

# %%
## Average monthly shelter costs for owned dwellings 
av_owned_shelter_cost = top_15_pop_df[top_15_pop_df['CHARACTERISTIC_ID'] == 1487]
av_owned_shelter_cost
# Out:
#                                 GEO_NAME  CHARACTERISTIC_ID  \
# 17272                            Halifax               1487
# 75154                             Québec               1487
# 111988                          Montréal               1487
# 140929                 Ottawa - Gatineau               1487
# 146191  Ottawa - Gatineau (Ontario part)               1487
# 180394                           Toronto               1487
# 183025                          Hamilton               1487
# 185656          St. Catharines - Niagara               1487
# 188287  Kitchener - Cambridge - Waterloo               1487
# 206704                            London               1487
# 211966                           Windsor               1487
# 254062                          Winnipeg               1487
# 306682                           Calgary               1487
# 325099                          Edmonton               1487
# 369826                         Vancouver               1487
#
#                                       CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 17272     Average monthly shelter costs for owned dwel...          1370.0
# 75154     Average monthly shelter costs for owned dwel...          1201.0
# 111988    Average monthly shelter costs for owned dwel...          1420.0
# 140929    Average monthly shelter costs for owned dwel...          1562.0
# 146191    Average monthly shelter costs for owned dwel...          1648.0
# 180394    Average monthly shelter costs for owned dwel...          2108.0
# 183025    Average monthly shelter costs for owned dwel...          1690.0
# 185656    Average monthly shelter costs for owned dwel...          1336.0
# 188287    Average monthly shelter costs for owned dwel...          1612.0
# 206704    Average monthly shelter costs for owned dwel...          1412.0
# 211966    Average monthly shelter costs for owned dwel...          1262.0
# 254062    Average monthly shelter costs for owned dwel...          1342.0
# 306682    Average monthly shelter costs for owned dwel...          1802.0
# 325099    Average monthly shelter costs for owned dwel...          1720.0
# 369826    Average monthly shelter costs for owned dwel...          1980.0

# %%
## Median monthly shelter costs for rented dwellings 
med_rented_shelter_cost = top_15_pop_df[top_15_pop_df['CHARACTERISTIC_ID'] == 1494]
med_rented_shelter_cost
# Out:
#                                 GEO_NAME  CHARACTERISTIC_ID  \
# 17279                            Halifax               1494
# 75161                             Québec               1494
# 111995                          Montréal               1494
# 140936                 Ottawa - Gatineau               1494
# 146198  Ottawa - Gatineau (Ontario part)               1494
# 180401                           Toronto               1494
# 183032                          Hamilton               1494
# 185663          St. Catharines - Niagara               1494
# 188294  Kitchener - Cambridge - Waterloo               1494
# 206711                            London               1494
# 211973                           Windsor               1494
# 254069                          Winnipeg               1494
# 306689                           Calgary               1494
# 325106                          Edmonton               1494
# 369833                         Vancouver               1494
#
#                                       CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 17279     Median monthly shelter costs for rented dwel...          1170.0
# 75161     Median monthly shelter costs for rented dwel...           830.0
# 111995    Median monthly shelter costs for rented dwel...           880.0
# 140936    Median monthly shelter costs for rented dwel...          1230.0
# 146198    Median monthly shelter costs for rented dwel...          1370.0
# 180401    Median monthly shelter costs for rented dwel...          1540.0
# 183032    Median monthly shelter costs for rented dwel...          1210.0
# 185663    Median monthly shelter costs for rented dwel...          1080.0
# 188294    Median monthly shelter costs for rented dwel...          1300.0
# 206711    Median monthly shelter costs for rented dwel...          1110.0
# 211973    Median monthly shelter costs for rented dwel...           980.0
# 254069    Median monthly shelter costs for rented dwel...          1100.0
# 306689    Median monthly shelter costs for rented dwel...          1350.0
# 325106    Median monthly shelter costs for rented dwel...          1290.0
# 369833    Median monthly shelter costs for rented dwel...          1500.0

# %%
## Average monthly shelter costs for rented dwellings 
av_rented_shelter_cost = top_15_pop_df[top_15_pop_df['CHARACTERISTIC_ID'] == 1495]
av_rented_shelter_cost
# Out:
#                                 GEO_NAME  CHARACTERISTIC_ID  \
# 17280                            Halifax               1495
# 75162                             Québec               1495
# 111996                          Montréal               1495
# 140937                 Ottawa - Gatineau               1495
# 146199  Ottawa - Gatineau (Ontario part)               1495
# 180402                           Toronto               1495
# 183033                          Hamilton               1495
# 185664          St. Catharines - Niagara               1495
# 188295  Kitchener - Cambridge - Waterloo               1495
# 206712                            London               1495
# 211974                           Windsor               1495
# 254070                          Winnipeg               1495
# 306690                           Calgary               1495
# 325107                          Edmonton               1495
# 369834                         Vancouver               1495
#
#                                       CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 17280     Average monthly shelter costs for rented dwe...          1247.0
# 75162     Average monthly shelter costs for rented dwe...           905.0
# 111996    Average monthly shelter costs for rented dwe...           981.0
# 140937    Average monthly shelter costs for rented dwe...          1296.0
# 146199    Average monthly shelter costs for rented dwe...          1412.0
# 180402    Average monthly shelter costs for rented dwe...          1618.0
# 183033    Average monthly shelter costs for rented dwe...          1328.0
# 185664    Average monthly shelter costs for rented dwe...          1172.0
# 188295    Average monthly shelter costs for rented dwe...          1352.0
# 206712    Average monthly shelter costs for rented dwe...          1198.0
# 211974    Average monthly shelter costs for rented dwe...          1069.0
# 254070    Average monthly shelter costs for rented dwe...          1140.0
# 306690    Average monthly shelter costs for rented dwe...          1416.0
# 325107    Average monthly shelter costs for rented dwe...          1330.0
# 369834    Average monthly shelter costs for rented dwe...          1624.0

# %% [markdown]
# ###
