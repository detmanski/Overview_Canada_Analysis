# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
culture_vis_df= pd.DataFrame({"Province": ["British Columbia", "Alberta", "Manitoba", "Ontario", "Quebec", "Nova Scotia"],
                             "Making Music(%)": [15.8, 12.3, 17.2, 15.8, 11.6, 17.9],
                             "Theatre(%)": [0, 0, 0, 1.9, 0, 0],
                             "Audio-Visual and Interactive Media(%)": [4.5, 4, 0, 5.4, 2.6, 4.3],
                             "Dancing(%)": [9.8, 10.2, 7.4, 10.1, 7.1, 7.7],
                             "Visual Arts(%)": [14.8, 13.5, 11.4, 14.9, 8.5, 15],
                             "Crafting(%)": [18.5, 19.3, 18.6, 19.4, 11.2, 23.2],
                             "Writing(%)": [11.9, 11.7, 8.8, 13, 7.4, 10.4],
                             "Other Cultural Activities(%)": [5, 4.2, 6.4, 5.9, 3.6, 8.5],
                             })
culture_vis_df
# Out:
#            Province  Making Music(%)  Theatre(%)  \
# 0  British Columbia             15.8         0.0
# 1           Alberta             12.3         0.0
# 2          Manitoba             17.2         0.0
# 3           Ontario             15.8         1.9
# 4            Quebec             11.6         0.0
# 5       Nova Scotia             17.9         0.0
#
#    Audio-Visual and Interactive Media(%)  Dancing(%)  Visual Arts(%)  \
# 0                                    4.5         9.8            14.8
# 1                                    4.0        10.2            13.5
# 2                                    0.0         7.4            11.4
# 3                                    5.4        10.1            14.9
# 4                                    2.6         7.1             8.5
# 5                                    4.3         7.7            15.0
#
#    Crafting(%)  Writing(%)  Other Cultural Activities(%)
# 0         18.5        11.9                           5.0
# 1         19.3        11.7                           4.2
# 2         18.6         8.8                           6.4
# 3         19.4        13.0                           5.9
# 4         11.2         7.4                           3.6
# 5         23.2        10.4                           8.5

# %%
culture_vis_df_2= pd.DataFrame({"Cultural Activities": ["Making Music(%)", "Theatre(%)", "Audio-Visual and Interactive Media(%)", "Dancing", "Visual Arts(%)", "Crafting(%)", "Writing(%)", "Other Cultural Activities"],
                                "British Columbia": [15.8, 0, 4.5, 9.8, 14.8, 18.5, 11.9, 5], 
                                "Alberta": [12.3, 0, 4, 10.2, 13.5, 19.3, 11.7, 4.2],
                                "Manitoba": [17.2, 0, 0, 7.4, 11.4, 18.6, 8.8, 6.4], 
                                "Ontario": [15.8, 1.9, 5.4, 10.1, 14.9, 19.4, 13, 5.9], 
                                "Quebec": [11.6, 0, 2.6, 7.1, 8.5, 11.2, 7.4, 3.6],
                                "Nova Scotia": [17.9, 0, 4.3, 7.7, 15, 23.2, 10.4, 8.5]
                               
                               })

culture_vis_df_2
# Out:
#                      Cultural Activities  British Columbia  Alberta  Manitoba  \
# 0                        Making Music(%)              15.8     12.3      17.2
# 1                             Theatre(%)               0.0      0.0       0.0
# 2  Audio-Visual and Interactive Media(%)               4.5      4.0       0.0
# 3                                Dancing               9.8     10.2       7.4
# 4                         Visual Arts(%)              14.8     13.5      11.4
# 5                            Crafting(%)              18.5     19.3      18.6
# 6                             Writing(%)              11.9     11.7       8.8
# 7              Other Cultural Activities               5.0      4.2       6.4
#
#    Ontario  Quebec  Nova Scotia
# 0     15.8    11.6         17.9
# 1      1.9     0.0          0.0
# 2      5.4     2.6          4.3
# 3     10.1     7.1          7.7
# 4     14.9     8.5         15.0
# 5     19.4    11.2         23.2
# 6     13.0     7.4         10.4
# 7      5.9     3.6          8.5

# %%
culture_vis_df.plot(kind="bar", x= "Province", y= "Making Music(%)", figsize=(4,4))
plt.xlabel("Making Music")
plt.ylabel("Percent Participation")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
string = 'Resources/condensed_culture_df.csv'
condensed_df = pd.read_csv(string)
condensed_df
# Out:
#     Unnamed: 0            Name  Participation in Cultural Activities (%)
# 0            0         Halifax                                      60.9
# 1            1          Québec                                      40.3
# 2            2        Montréal                                      40.3
# 3            3        Gatineau                                      40.3
# 4            4          Ottawa                                      54.8
# 5            5         Toronto                                      54.8
# 6            6        Hamilton                                      54.8
# 7            7  St. Catherines                                      54.8
# 8            8       Kitchener                                      54.8
# 9            9          London                                      54.8
# 10          10         Windsor                                      54.8
# 11          11        Winnipeg                                      52.7
# 12          12         Calgary                                      52.2
# 13          13        Edmonton                                      52.2
# 14          14       Vancouver                                      54.4

# %%
condensed_df.plot(kind="bar", x= "Name", y= "Participation in Cultural Activities (%)", figsize=(6,6), legend=False)
plt.xlabel("City")
plt.ylabel("Percent Participation")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
activities= culture_vis_df_2["Cultural Activities"]
participation= culture_vis_df_2["British Columbia"]
colors = ["yellow","green","lightblue","orange","red","purple","pink","yellowgreen"]
pie_chart1= plt.pie(participation, labels= activities, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
