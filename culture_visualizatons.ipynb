# %%
# %matplotlib notebook

# %%
#import dependancies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Creating a dataframe with data previously collected and saving to csv
culture_vis_df= pd.DataFrame({"Province": ["British Columbia", "Alberta", "Manitoba", "Ontario", "Quebec", "Nova Scotia"],
                             "Making Music(%)": [15.8, 12.3, 17.2, 15.8, 11.6, 17.9],
                             "Theatre(%)": [0, 0, 0, 1.9, 0, 0],
                             "Audio-Visual and Interactive Media(%)": [4.5, 4, 0, 5.4, 2.6, 4.3],
                             "Dancing(%)": [9.8, 10.2, 7.4, 10.1, 7.1, 7.7],
                             "Visual Arts(%)": [14.8, 13.5, 11.4, 14.9, 8.5, 15],
                             "Crafting(%)": [18.5, 19.3, 18.6, 19.4, 11.2, 23.2],
                             "Writing(%)": [11.9, 11.7, 8.8, 13, 7.4, 10.4],
                             "Other Cultural Activities(%)": [5, 4.2, 6.4, 5.9, 3.6, 8.5],
                             })
culture_vis_df.to_csv("Resources/culture_vis_df.csv")

# %%
#Creating a second dataframe in a different layout and saving to csv
culture_vis_df_2= pd.DataFrame({"Cultural Activities": ["Making Music(%)", "Theatre(%)", "Audio-Visual and Interactive Media(%)", "Dancing", "Visual Arts(%)", "Crafting(%)", "Writing(%)", "Other Cultural Activities"],
                                "British Columbia": [15.8, 0, 4.5, 9.8, 14.8, 18.5, 11.9, 5], 
                                "Alberta": [12.3, 0, 4, 10.2, 13.5, 19.3, 11.7, 4.2],
                                "Manitoba": [17.2, 0, 0, 7.4, 11.4, 18.6, 8.8, 6.4], 
                                "Ontario": [15.8, 1.9, 5.4, 10.1, 14.9, 19.4, 13, 5.9], 
                                "Quebec": [11.6, 0, 2.6, 7.1, 8.5, 11.2, 7.4, 3.6],
                                "Nova Scotia": [17.9, 0, 4.3, 7.7, 15, 23.2, 10.4, 8.5]
                               
                               })

culture_vis_df_2.to_csv("Resources/culture_vis_df_2.csv")

# %%
#Quick plot showing only one metric of activities by province
culture_vis_df.plot(kind="bar", x= "Province", y= "Making Music(%)", figsize=(4,4))
plt.xlabel("Making Music")
plt.ylabel("Percent Participation")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
#Pulling the condensed df to plot in a way that ties into the rest of the presentation
string = 'Resources/condensed_culture_df.csv'
condensed_df = pd.read_csv(string)
condensed_df
# Out:
#     Unnamed: 0            Name  Participation in Cultural Activities (%)
# 0            0         Halifax                                      60.9
# 1            1          Québec                                      40.3
# 2            2        Montréal                                      40.3
# 3            3        Gatineau                                      40.3
# 4            4          Ottawa                                      54.8
# 5            5         Toronto                                      54.8
# 6            6        Hamilton                                      54.8
# 7            7  St. Catherines                                      54.8
# 8            8       Kitchener                                      54.8
# 9            9          London                                      54.8
# 10          10         Windsor                                      54.8
# 11          11        Winnipeg                                      52.7
# ...

# %%
#Showing the overall participation by city as a overall vies
condensed_df.plot(kind="bar", x= "Name", y= "Participation in Cultural Activities (%)", figsize=(6,6), legend=False)
plt.xlabel("City")
plt.ylabel("Percent Participation")
plt.title("Overall Participation in Cultural Activities by City")
plt.savefig("cities_overall_participation.png")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#Creating keywords to use in visualizations
making_music = culture_vis_df["Making Music(%)"]
dancing = culture_vis_df["Dancing(%)"]
visual_arts = culture_vis_df["Visual Arts(%)"]
theatre = culture_vis_df["Theatre(%)"]
crafting = culture_vis_df["Crafting(%)"]
writing = culture_vis_df["Writing(%)"]
auto_visual = culture_vis_df["Audio-Visual and Interactive Media(%)"]
other = culture_vis_df["Other Cultural Activities(%)"]
labels = culture_vis_df["Province"]

# %%
#Stacked bar graph code 
fig,ax = plt.subplots(1, figsize=(8,8))
ax.bar(labels, crafting, width=(0.75), label= "Crafting")
ax.bar(labels, making_music, width=(0.75), label="Music")
ax.bar(labels, visual_arts, width=(0.75), label= "Visual Art")
ax.bar(labels, writing, width=(0.75), label= "Writing")
ax.bar(labels, dancing, width=(0.75), label="Dancing")
ax.bar(labels, other, width=(0.75), label= "Other")
ax.bar(labels, auto_visual, width=(0.75), label="AV")
ax.bar(labels, theatre, width=(0.75), label="Theatre")
ax.set_ylabel("Percent Participation")
ax.set_xlabel("Province")
ax.set_title("Participation In Cultural Activities")
ax.legend(loc='upper left')
pos = ax.get_position()
ax.set_position([pos.x0, pos.y0, pos.width * 0.9, pos.height])
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
