# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
bc_df = pd.read_csv("Resources/bc_df.csv")
bc_df
# Out:
#     Unnamed: 0          Province                         Cultural activities  \
# 0            0  British Columbia                                Making music
# 1            1  British Columbia                                Making music
# 2            2  British Columbia                                     Theatre
# 3            3  British Columbia                                     Theatre
# 4            4  British Columbia          Audio-visual and interactive media
# 5            5  British Columbia          Audio-visual and interactive media
# 6            6  British Columbia                                     Dancing
# 7            7  British Columbia                                     Dancing
# 8            8  British Columbia                                 Visual arts
# 9            9  British Columbia                                 Visual arts
# 10          10  British Columbia                                    Crafting
# ...

# %%
bc_df =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mc/ktgbqxj54dd2hpjj2g0t7x4c0000gn/T/ipykernel_31707/274639380.py in <module>
#       1 bc_df = np.array([6,2])
# ----> 2 bc_df.describe
#       3
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
# Out:
#   File "/var/folders/mc/ktgbqxj54dd2hpjj2g0t7x4c0000gn/T/ipykernel_31707/168135057.py", line 2
#     plt.bar(x_axis, (bc_df["Type")
#                                  ^
# SyntaxError: invalid syntax
