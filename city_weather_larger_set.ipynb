# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# %%
# List of cities
cities = ["St. John's", 'Grand Falls-Windsor', 'Gander', 'Corner Brook',
       'Charlottetown', 'Summerside', 'Halifax', 'Kentville', 'Truro',
       'New Glasgow', 'Cape Breton', 'Moncton', 'Saint John',
       'Fredericton', 'Bathurst', 'Miramichi', 'Campbellton',
       'Campbellton (New Brunswick part)', 'Campbellton (Quebec part)',
       'Edmundston', 'Matane', 'Rimouski', 'Rivière-du-Loup',
       'Baie-Comeau', 'Saguenay', 'Alma', 'Dolbeau-Mistassini',
       'Sept-Îles', 'Québec', 'Sainte-Marie', 'Saint-Georges',
       'Thetford Mines', 'Sherbrooke', 'Cowansville', 'Victoriaville',
       'Trois-Rivières', 'Shawinigan', 'Drummondville', 'Granby',
       'Saint-Hyacinthe', 'Sorel-Tracy', 'Joliette', 'Montréal',
       'Salaberry-de-Valleyfield', 'Sainte-Agathe-des-Monts', 'Lachute',
       "Val-d'Or", 'Amos', 'Rouyn-Noranda', 'Cornwall', 'Hawkesbury',
       'Hawkesbury (Quebec part)', 'Hawkesbury (Ontario part)',
       'Ottawa - Gatineau', 'Ottawa - Gatineau (Quebec part)',
       'Ottawa - Gatineau (Ontario part)', 'Brockville', 'Pembroke',
       'Petawawa', 'Kingston', 'Belleville - Quinte West', 'Cobourg',
       'Port Hope', 'Peterborough', 'Kawartha Lakes', 'Centre Wellington',
       'Oshawa', 'Ingersoll', 'Toronto', 'Hamilton',
       'St. Catharines - Niagara', 'Kitchener - Cambridge - Waterloo',
       'Brantford', 'Woodstock', 'Tillsonburg', 'Norfolk', 'Guelph',
       'Stratford', 'London', 'Chatham-Kent', 'Windsor', 'Sarnia', 'Essa',
       'Wasaga Beach', 'Owen Sound', 'Collingwood', 'Barrie', 'Orillia',
       'Midland', 'North Bay', 'Greater Sudbury / Grand Sudbury',
       'Elliot Lake', 'Timmins', 'Sault Ste. Marie', 'Thunder Bay',
       'Kenora', 'Winnipeg', 'Winkler', 'Steinbach', 'Portage la Prairie',
       'Brandon', 'Thompson', 'Regina', 'Yorkton', 'Moose Jaw',
       'Swift Current', 'Saskatoon', 'North Battleford', 'Prince Albert',
       'Estevan', 'Weyburn', 'Medicine Hat', 'Brooks', 'Lethbridge',
       'Okotoks', 'High River', 'Calgary', 'Strathmore', 'Canmore',
       'Red Deer', 'Sylvan Lake', 'Lacombe', 'Camrose', 'Edmonton',
       'Lloydminster', 'Lloydminster (Saskatchewan part)',
       'Lloydminster (Alberta part)', 'Grande Prairie', 'Wood Buffalo',
       'Wetaskiwin', 'Cranbrook', 'Nelson', 'Trail', 'Penticton',
       'Kelowna', 'Vernon', 'Salmon Arm', 'Kamloops', 'Chilliwack',
       'Abbotsford - Mission', 'Vancouver', 'Squamish', 'Victoria',
       'Ladysmith', 'Duncan', 'Nanaimo', 'Parksville', 'Port Alberni',
       'Courtenay', 'Campbell River', 'Powell River', 'Williams Lake',
       'Quesnel', 'Prince Rupert', 'Terrace', 'Prince George',
       'Dawson Creek', 'Fort St. John', 'Whitehorse', 'Yellowknife']

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?q=" 

#https://api.openweathermap.org/data/2.5/weather?q={city name},{country code}&appid={API key}

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"
    city_url = f"{url}{city},CA&appid={weather_api_key}"
        
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response_json = requests.get(city_url).json()
        #json.dumps(response_json, indent=4, sort_keys=True)
        #city_weather = response_json["weather"]
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json["coord"]["lat"]
        city_lng = response_json["coord"]["lon"]
        city_max_temp = response_json["main"]["temp_max"]
        city_humidity = response_json["main"]["humidity"]
        city_clouds = response_json["clouds"]["all"]
        city_wind = response_json["wind"]["speed"]
        city_country = response_json["sys"]["country"]
        city_date = response_json["dt"]
      

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp-273.15,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | St. John's
# Processing Record 2 of Set 1 | Grand Falls-Windsor
# Processing Record 3 of Set 1 | Gander
# Processing Record 4 of Set 1 | Corner Brook
# Processing Record 5 of Set 1 | Charlottetown
# Processing Record 6 of Set 1 | Summerside
# Processing Record 7 of Set 1 | Halifax
# Processing Record 8 of Set 1 | Kentville
# Processing Record 9 of Set 1 | Truro
# Processing Record 10 of Set 1 | New Glasgow
# Processing Record 11 of Set 1 | Cape Breton
# City not found. Skipping...
# Processing Record 12 of Set 1 | Moncton
# Processing Record 13 of Set 1 | Saint John
# Processing Record 14 of Set 1 | Fredericton
# Processing Record 15 of Set 1 | Bathurst
# Processing Record 16 of Set 1 | Miramichi
# Processing Record 17 of Set 1 | Campbellton
# Processing Record 18 of Set 1 | Campbellton (New Brunswick part)
# City not found. Skipping...
# Processing Record 19 of Set 1 | Campbellton (Quebec part)
# City not found. Skipping...
# Processing Record 20 of Set 1 | Edmundston
# Processing Record 21 of Set 1 | Matane
# Processing Record 22 of Set 1 | Rimouski
# Processing Record 23 of Set 1 | Rivière-du-Loup
# Processing Record 24 of Set 1 | Baie-Comeau
# Processing Record 25 of Set 1 | Saguenay
# Processing Record 26 of Set 1 | Alma
# Processing Record 27 of Set 1 | Dolbeau-Mistassini
# Processing Record 28 of Set 1 | Sept-Îles
# Processing Record 29 of Set 1 | Québec
# Processing Record 30 of Set 1 | Sainte-Marie
# Processing Record 31 of Set 1 | Saint-Georges
# Processing Record 32 of Set 1 | Thetford Mines
# Processing Record 33 of Set 1 | Sherbrooke
# Processing Record 34 of Set 1 | Cowansville
# Processing Record 35 of Set 1 | Victoriaville
# Processing Record 36 of Set 1 | Trois-Rivières
# Processing Record 37 of Set 1 | Shawinigan
# Processing Record 38 of Set 1 | Drummondville
# Processing Record 39 of Set 1 | Granby
# Processing Record 40 of Set 1 | Saint-Hyacinthe
# Processing Record 41 of Set 1 | Sorel-Tracy
# Processing Record 42 of Set 1 | Joliette
# Processing Record 43 of Set 1 | Montréal
# Processing Record 44 of Set 1 | Salaberry-de-Valleyfield
# Processing Record 45 of Set 1 | Sainte-Agathe-des-Monts
# Processing Record 46 of Set 1 | Lachute
# Processing Record 47 of Set 1 | Val-d'Or
# Processing Record 48 of Set 1 | Amos
# Processing Record 49 of Set 1 | Rouyn-Noranda
# Processing Record 50 of Set 1 | Cornwall
# Processing Record 0 of Set 2 | Hawkesbury
# Processing Record 1 of Set 2 | Hawkesbury (Quebec part)
# City not found. Skipping...
# Processing Record 2 of Set 2 | Hawkesbury (Ontario part)
# City not found. Skipping...
# Processing Record 3 of Set 2 | Ottawa - Gatineau
# City not found. Skipping...
# Processing Record 4 of Set 2 | Ottawa - Gatineau (Quebec part)
# City not found. Skipping...
# Processing Record 5 of Set 2 | Ottawa - Gatineau (Ontario part)
# City not found. Skipping...
# Processing Record 6 of Set 2 | Brockville
# Processing Record 7 of Set 2 | Pembroke
# Processing Record 8 of Set 2 | Petawawa
# Processing Record 9 of Set 2 | Kingston
# Processing Record 10 of Set 2 | Belleville - Quinte West
# City not found. Skipping...
# Processing Record 11 of Set 2 | Cobourg
# Processing Record 12 of Set 2 | Port Hope
# Processing Record 13 of Set 2 | Peterborough
# Processing Record 14 of Set 2 | Kawartha Lakes
# Processing Record 15 of Set 2 | Centre Wellington
# City not found. Skipping...
# Processing Record 16 of Set 2 | Oshawa
# Processing Record 17 of Set 2 | Ingersoll
# Processing Record 18 of Set 2 | Toronto
# Processing Record 19 of Set 2 | Hamilton
# Processing Record 20 of Set 2 | St. Catharines - Niagara
# City not found. Skipping...
# Processing Record 21 of Set 2 | Kitchener - Cambridge - Waterloo
# City not found. Skipping...
# Processing Record 22 of Set 2 | Brantford
# Processing Record 23 of Set 2 | Woodstock
# Processing Record 24 of Set 2 | Tillsonburg
# Processing Record 25 of Set 2 | Norfolk
# City not found. Skipping...
# Processing Record 26 of Set 2 | Guelph
# Processing Record 27 of Set 2 | Stratford
# Processing Record 28 of Set 2 | London
# Processing Record 29 of Set 2 | Chatham-Kent
# Processing Record 30 of Set 2 | Windsor
# Processing Record 31 of Set 2 | Sarnia
# Processing Record 32 of Set 2 | Essa
# City not found. Skipping...
# Processing Record 33 of Set 2 | Wasaga Beach
# Processing Record 34 of Set 2 | Owen Sound
# Processing Record 35 of Set 2 | Collingwood
# Processing Record 36 of Set 2 | Barrie
# Processing Record 37 of Set 2 | Orillia
# Processing Record 38 of Set 2 | Midland
# Processing Record 39 of Set 2 | North Bay
# Processing Record 40 of Set 2 | Greater Sudbury / Grand Sudbury
# City not found. Skipping...
# Processing Record 41 of Set 2 | Elliot Lake
# Processing Record 42 of Set 2 | Timmins
# Processing Record 43 of Set 2 | Sault Ste. Marie
# Processing Record 44 of Set 2 | Thunder Bay
# Processing Record 45 of Set 2 | Kenora
# Processing Record 46 of Set 2 | Winnipeg
# Processing Record 47 of Set 2 | Winkler
# Processing Record 48 of Set 2 | Steinbach
# Processing Record 49 of Set 2 | Portage la Prairie
# Processing Record 0 of Set 3 | Brandon
# Processing Record 1 of Set 3 | Thompson
# Processing Record 2 of Set 3 | Regina
# Processing Record 3 of Set 3 | Yorkton
# Processing Record 4 of Set 3 | Moose Jaw
# Processing Record 5 of Set 3 | Swift Current
# Processing Record 6 of Set 3 | Saskatoon
# Processing Record 7 of Set 3 | North Battleford
# Processing Record 8 of Set 3 | Prince Albert
# Processing Record 9 of Set 3 | Estevan
# Processing Record 10 of Set 3 | Weyburn
# Processing Record 11 of Set 3 | Medicine Hat
# Processing Record 12 of Set 3 | Brooks
# Processing Record 13 of Set 3 | Lethbridge
# Processing Record 14 of Set 3 | Okotoks
# Processing Record 15 of Set 3 | High River
# Processing Record 16 of Set 3 | Calgary
# Processing Record 17 of Set 3 | Strathmore
# Processing Record 18 of Set 3 | Canmore
# Processing Record 19 of Set 3 | Red Deer
# Processing Record 20 of Set 3 | Sylvan Lake
# Processing Record 21 of Set 3 | Lacombe
# Processing Record 22 of Set 3 | Camrose
# Processing Record 23 of Set 3 | Edmonton
# Processing Record 24 of Set 3 | Lloydminster
# Processing Record 25 of Set 3 | Lloydminster (Saskatchewan part)
# City not found. Skipping...
# Processing Record 26 of Set 3 | Lloydminster (Alberta part)
# City not found. Skipping...
# Processing Record 27 of Set 3 | Grande Prairie
# Processing Record 28 of Set 3 | Wood Buffalo
# City not found. Skipping...
# Processing Record 29 of Set 3 | Wetaskiwin
# Processing Record 30 of Set 3 | Cranbrook
# Processing Record 31 of Set 3 | Nelson
# Processing Record 32 of Set 3 | Trail
# Processing Record 33 of Set 3 | Penticton
# Processing Record 34 of Set 3 | Kelowna
# Processing Record 35 of Set 3 | Vernon
# Processing Record 36 of Set 3 | Salmon Arm
# Processing Record 37 of Set 3 | Kamloops
# Processing Record 38 of Set 3 | Chilliwack
# Processing Record 39 of Set 3 | Abbotsford - Mission
# City not found. Skipping...
# Processing Record 40 of Set 3 | Vancouver
# Processing Record 41 of Set 3 | Squamish
# Processing Record 42 of Set 3 | Victoria
# Processing Record 43 of Set 3 | Ladysmith
# Processing Record 44 of Set 3 | Duncan
# Processing Record 45 of Set 3 | Nanaimo
# Processing Record 46 of Set 3 | Parksville
# Processing Record 47 of Set 3 | Port Alberni
# Processing Record 48 of Set 3 | Courtenay
# Processing Record 49 of Set 3 | Campbell River
# Processing Record 0 of Set 4 | Powell River
# Processing Record 1 of Set 4 | Williams Lake
# Processing Record 2 of Set 4 | Quesnel
# Processing Record 3 of Set 4 | Prince Rupert
# Processing Record 4 of Set 4 | Terrace
# Processing Record 5 of Set 4 | Prince George
# Processing Record 6 of Set 4 | Dawson Creek
# Processing Record 7 of Set 4 | Fort St. John
# Processing Record 8 of Set 4 | Whitehorse
# Processing Record 9 of Set 4 | Yellowknife
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Find out how many cities were found
len(city_data)
# Out:
# 141

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          141
# Lat           141
# Lng           141
# Max Temp      141
# Humidity      141
# Cloudiness    141
# Wind Speed    141
# Country       141
# Date          141
# dtype: int64

# %%
# Display sample data
city_data_df
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             St. John's  47.5649  -52.7093     -9.46        82          98
# 1    Grand Falls-Windsor  48.9332  -55.6649    -18.07        97          41
# 2                 Gander  48.9682  -54.5906    -12.13        72          79
# 3           Corner Brook  48.9667  -57.9484    -11.47        91          98
# 4          Charlottetown  46.2352  -63.1267     -6.00        68          99
# ..                   ...      ...       ...       ...       ...         ...
# 136        Prince George  53.9166 -122.7530      3.49        76         100
# 137         Dawson Creek  55.7666 -120.2362     -2.29        95         100
# 138        Fort St. John  56.2499 -120.8529     -1.06        86         100
# 139           Whitehorse  60.7161 -135.0538    -10.63        96         100
# 140          Yellowknife  62.4560 -114.3525    -23.58        76          36
#
#      Wind Speed Country        Date
# 0          3.58      CA  1676005814
# 1          1.87      CA  1676005973
# 2          5.36      CA  1676006027
# 3          2.81      CA  1676006027
# 4          1.34      CA  1676006028
# ..          ...     ...         ...
# 136        2.49      CA  1676006070
# 137        1.35      CA  1676006070
# 138        3.09      CA  1676006071
# 139        1.70      CA  1676006038
# 140        1.34      CA  1676005803
#
# [141 rows x 9 columns]

# %%
city_data_df.index.name = 'City_IDWeather'
city_data_df
# Out:
#                                City      Lat       Lng  Max Temp  Humidity  \
# City_IDWeather
# 0                        St. John's  47.5649  -52.7093     -9.46        82
# 1               Grand Falls-Windsor  48.9332  -55.6649    -18.07        97
# 2                            Gander  48.9682  -54.5906    -12.13        72
# 3                      Corner Brook  48.9667  -57.9484    -11.47        91
# 4                     Charlottetown  46.2352  -63.1267     -6.00        68
# ...                             ...      ...       ...       ...       ...
# 136                   Prince George  53.9166 -122.7530      3.49        76
# 137                    Dawson Creek  55.7666 -120.2362     -2.29        95
# 138                   Fort St. John  56.2499 -120.8529     -1.06        86
# 139                      Whitehorse  60.7161 -135.0538    -10.63        96
# 140                     Yellowknife  62.4560 -114.3525    -23.58        76
#
#                 Cloudiness  Wind Speed Country        Date
# City_IDWeather
# 0                       98        3.58      CA  1676005814
# 1                       41        1.87      CA  1676005973
# 2                       79        5.36      CA  1676006027
# 3                       98        2.81      CA  1676006027
# 4                       99        1.34      CA  1676006028
# ...                    ...         ...     ...         ...
# 136                    100        2.49      CA  1676006070
# 137                    100        1.35      CA  1676006070
# 138                    100        3.09      CA  1676006071
# 139                    100        1.70      CA  1676006038
# 140                     36        1.34      CA  1676005803
#
# [141 rows x 9 columns]

# %%
# Export the merged_df into a csv
city_data_df.to_csv("Output/weather_data_larger_set.csv", index_label="City_ID2")
