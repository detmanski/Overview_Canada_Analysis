# %%
import pandas as pd

# %%
crime_df = pd.read_csv('Output/crime_data.csv')
crime_df
# Out:
#     City_ID2  City_ID2.1                              City  \
# 0          0       18426                           Halifax
# 1          1       18534                            Québec
# 2          2       18588                          Montréal
# 3          3       18606   Ottawa - Gatineau (Quebec part)
# 4          4       18660  Ottawa - Gatineau (Ontario part)
# 5          5       18732                           Toronto
# 6          6       18750                          Hamilton
# 7          7       18768          St. Catharines - Niagara
# 8          8       18786  Kitchener - Cambridge - Waterloo
# 9          9       18840                            London
# 10        10       18858                           Windsor
# 11        11       18948                          Winnipeg
# 12        12       19056                           Calgary
# 13        13       19074                          Edmonton
# 14        14       19146                         Vancouver
#
# ...

# %%
weather_df = pd.read_csv('Output/weather_data.csv')
weather_df
# Out:
#     City_ID2  Wind Speed  Max Temp  City_ID2.1                           GEO  \
# 0          0        2.06     -0.44       18426                       Halifax
# 1          1       11.32     -2.11       18534                        Québec
# 2          2        6.17      3.47       18588                      Montréal
# 3          3        6.17      1.53       18660               Ottawa-Gatineau
# 4          4        6.17      1.67       18606               Ottawa-Gatineau
# 5          5        6.17      6.71       18732                       Toronto
# 6          6       14.92      6.34       18750                      Hamilton
# 7          7       12.86      8.47       18768         St.Catharines-Niagara
# 8          8        6.17      4.87       18786  Kitchener-Cambridge-Waterloo
# 9          9        8.75      4.18       18840                        London
# 10        10        8.23      5.54       18858                       Windsor
# ...

# %%
income_df = pd.read_csv('Output/income_data.csv')
income_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/0p/153rzb85259_hj2vtznb45r00000gn/T/ipykernel_11586/4082392520.py in <module>
# ----> 1 income_df = pd.read_csv('Output/income_data.csv')
#       2 income_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
merged_df1 = crime_df.merge(weather_df, on='City_ID2', how='inner')
merged_df1
# Out:
#     City_ID2  City_ID2.1_x                            City_x  \
# 0          0         18426                           Halifax
# 1          1         18534                            Québec
# 2          2         18588                          Montréal
# 3          3         18606   Ottawa - Gatineau (Quebec part)
# 4          4         18660  Ottawa - Gatineau (Ontario part)
# 5          5         18732                           Toronto
# 6          6         18750                          Hamilton
# 7          7         18768          St. Catharines - Niagara
# 8          8         18786  Kitchener - Cambridge - Waterloo
# 9          9         18840                            London
# 10        10         18858                           Windsor
# 11        11         18948                          Winnipeg
# 12        12         19056                           Calgary
# 13        13         19074                          Edmonton
# ...

# %%
merged_df2 = merged_df1.merge(income_df, on='City_ID2', how='inner')
merged_df1
