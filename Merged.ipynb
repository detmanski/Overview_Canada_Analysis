# %%
import pandas as pd

# %%
crime_df = pd.read_csv('Output/crime_data.csv')
crime_df
# Out:
#     City_ID2  City_ID2.1                              City  \
# 0          0       18426                           Halifax
# 1          1       18534                            Québec
# 2          2       18588                          Montréal
# 3          3       18606   Ottawa - Gatineau (Quebec part)
# 4          4       18660  Ottawa - Gatineau (Ontario part)
# 5          5       18732                           Toronto
# 6          6       18750                          Hamilton
# 7          7       18768          St. Catharines - Niagara
# 8          8       18786  Kitchener - Cambridge - Waterloo
# 9          9       18840                            London
# 10        10       18858                           Windsor
# 11        11       18948                          Winnipeg
# 12        12       19056                           Calgary
# 13        13       19074                          Edmonton
# 14        14       19146                         Vancouver
#
# ...

# %%
weather_df = pd.read_csv('Output/weather_data.csv')
weather_df
# Out:
#     City_ID2  Wind Speed  Max Temp                           GEO  City_ID2.1  \
# 0          0        2.06     -0.44                       Halifax       18426
# 1          1       11.32     -2.11                        Québec       18534
# 2          2        6.17      3.47                      Montréal       18588
# 3          3        6.17      1.53               Ottawa-Gatineau       18660
# 4          4        6.17      1.67               Ottawa-Gatineau       18606
# 5          5        6.17      6.71                       Toronto       18732
# 6          6       14.92      6.34                      Hamilton       18750
# 7          7       12.86      8.47         St.Catharines-Niagara       18768
# 8          8        6.17      4.87  Kitchener-Cambridge-Waterloo       18786
# 9          9        8.75      4.18                        London       18840
# 10        10        8.23      5.54                       Windsor       18858
# ...
